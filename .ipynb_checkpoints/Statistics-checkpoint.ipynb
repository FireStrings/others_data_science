# %%
import pandas as pd
import seaborn as sns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data = pd.read_csv("../../data/Sales_Transactions_Dataset_Weekly.csv")

# %%
data2 = data.iloc[:, 55:]

# %%
data2.describe()
# Out:
#        Normalized 0  Normalized 1  Normalized 2  Normalized 3  Normalized 4  \
# count    811.000000    811.000000    811.000000    811.000000    811.000000
# mean       0.289396      0.299100      0.306732      0.319852      0.326905
# std        0.266307      0.281343      0.284234      0.296498      0.297291
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.250000      0.280000      0.290000      0.290000      0.310000
# 75%        0.500000      0.500000      0.500000      0.535000      0.550000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        Normalized 5  Normalized 6  Normalized 7  Normalized 8  Normalized 9  \
# count    811.000000    811.000000    811.000000     811.00000    811.000000
# mean       0.319420      0.332848      0.326572       0.32434      0.326843
# ...

# %%
# data2.hist()
oc = data2.columns
nc = ["w"+str(x) for x in range(0,52)]

    
data3 = data2.rename(columns=dict(zip(oc, nc)))

# %%
data3.head()
# Out:
#      w0    w1    w2    w3    w4    w5    w6    w7    w8    w9   w10   w11  \
# 0  0.44  0.50  0.39  0.28  0.56  0.50  0.61  1.00  0.17  0.61  0.44  0.61
# 1  0.70  0.60  0.30  0.20  0.70  0.10  0.60  0.30  0.30  0.30  0.20  0.20
# 2  0.36  0.73  0.45  0.55  0.64  0.45  0.36  0.91  0.82  0.27  1.00  0.55
# 3  0.59  0.35  0.65  0.18  0.41  0.24  0.41  0.65  0.65  0.53  0.35  0.12
# 4  0.33  0.13  0.67  0.53  0.20  0.27  0.40  0.73  0.40  0.40  0.53  1.00
#
#     w12   w13   w14   w15   w16   w17   w18   w19   w20   w21   w22   w23  \
# 0  0.72  0.33  0.33  0.33  0.61  0.33  0.00  0.50  0.11  0.44  0.22  0.50
# 1  0.60  0.20  0.00  0.60  0.20  0.70  0.70  0.90  0.40  0.70  0.20  0.40
# 2  0.09  0.36  0.82  0.45  0.36  0.73  0.64  0.36  0.36  0.91  0.73  0.45
# 3  0.18  0.12  0.76  0.29  0.53  0.41  0.76  0.12  0.24  0.29  0.53  0.29
# 4  0.33  0.07  0.67  0.33  0.47  0.80  0.20  0.67  0.53  0.20  0.47  0.40
#
# ...

# %%
data3.insert(loc=0, column='pc', value=data.Product_Code.values)

# %%
data3.head()
# Out:
#    pc    w0    w1    w2    w3    w4    w5    w6    w7    w8    w9   w10   w11  \
# 0  P1  0.44  0.50  0.39  0.28  0.56  0.50  0.61  1.00  0.17  0.61  0.44  0.61
# 1  P2  0.70  0.60  0.30  0.20  0.70  0.10  0.60  0.30  0.30  0.30  0.20  0.20
# 2  P3  0.36  0.73  0.45  0.55  0.64  0.45  0.36  0.91  0.82  0.27  1.00  0.55
# 3  P4  0.59  0.35  0.65  0.18  0.41  0.24  0.41  0.65  0.65  0.53  0.35  0.12
# 4  P5  0.33  0.13  0.67  0.53  0.20  0.27  0.40  0.73  0.40  0.40  0.53  1.00
#
#     w12   w13   w14   w15   w16   w17   w18   w19   w20   w21   w22   w23  \
# 0  0.72  0.33  0.33  0.33  0.61  0.33  0.00  0.50  0.11  0.44  0.22  0.50
# 1  0.60  0.20  0.00  0.60  0.20  0.70  0.70  0.90  0.40  0.70  0.20  0.40
# 2  0.09  0.36  0.82  0.45  0.36  0.73  0.64  0.36  0.36  0.91  0.73  0.45
# 3  0.18  0.12  0.76  0.29  0.53  0.41  0.76  0.12  0.24  0.29  0.53  0.29
# 4  0.33  0.07  0.67  0.33  0.47  0.80  0.20  0.67  0.53  0.20  0.47  0.40
#
# ...

# %%
sns.histplot(data=data3, x="w9", binwidth=0.1)
# Out:
# <AxesSubplot:xlabel='w9', ylabel='Count'>

# %%
data3.w1.describe()
# Out:
# count    811.000000
# mean       0.299100
# std        0.281343
# min        0.000000
# 25%        0.000000
# 50%        0.280000
# 75%        0.500000
# max        1.000000
# Name: w1, dtype: float64

# %%
data3.w3.describe()
# Out:
# count    811.000000
# mean       0.319852
# std        0.296498
# min        0.000000
# 25%        0.000000
# 50%        0.290000
# 75%        0.535000
# max        1.000000
# Name: w3, dtype: float64
