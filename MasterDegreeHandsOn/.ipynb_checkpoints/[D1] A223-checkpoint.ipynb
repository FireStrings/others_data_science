# %% [markdown]
# # Definições
# Esse notebook irá analisar dados da estação A223, na cidade de Alto Parnaiba, no Maranhão. O propósito aqui é realizar o EDA dos dados e, como output, obter alguams conclusões.
#
# ### Possíveis análises:
# - Medir o nivel de radiação por ano, mes e horário do dia;
# - Confirmar se há relação entre as categorias criadas (hue) com a radiação;
# - Verificar estatísticas básicas (quantidades de nulls, media, desvio padrão, etc);
# - Remoção de colunas desnecessárias;
# - Feature engineering (juntar dois campos, criar campos category, etc)
# - Remoção de Outliers

# %% [markdown]
# ### Import das bibliotecas

# %%
import numpy as np
import seaborn as sns
import pandas as pd
from scipy.special import expit
from scipy.stats import zscore
from pandas.errors import SettingWithCopyWarning
import os
from os import listdir
from os import system

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)
warnings.simplefilter(action='ignore', category=SettingWithCopyWarning)


sns.set_theme(rc={'figure.figsize':(11.7,8.27)})

# %% [markdown]
# ### Métodos auxiliares

# %%
def getSigmoid():
    arr = np.arange(0, 1, 0.02)
    np.hstack(np.vstack(arr))
    def sigmoid(x):
        return 1/(1+expit(-x))
    
    sigmoid(arr)
    sns.scatterplot(x=arr, y=sigmoid(arr))

def get_files(n=1, lazy=True):
    cwd = os.getcwd()
    
    dict_data = {}
    
    listdir(cwd + "/data/estacoes_solares/BDM_INMET/")
    list_files = [x for x in listdir(cwd + "/data/estacoes_solares/BDM_INMET/") if ".csv" in x]

    if n:
        _range = list_files[0:n]
    else:
        _range = list_files
    
    for i in _range:
        # print("Processando arquivo " + i)
        
        code = i.split("_")[1]
        head = os.popen("head -10 data/estacoes_solares/BDM_INMET/" + i).read()

        if lazy:
            data = "data/estacoes_solares/BDM_INMET/"+i
        else:
            data = pd.read_csv("data/estacoes_solares/BDM_INMET/"+i, sep=";", skiprows=10)
        
        dict_data[code] = [head, data]

    return dict_data

def getDictToRenameDataFrame(list_columns):
    list_columns_new = []
    for i in list_columns: 
        list_columns_new.append(str
              .lower(i)
              .replace(" ", "_")
              . replace("(", "_")
              .replace(")", "")
              .replace("/", "")
              .replace("²", "2")
              .replace("°", "")
              .replace("%", "perc")
              .replace("._", "_")
              .replace(".", "_")
              .replace("__", "_")
              .replace("_-_", "_")
              .replace(",_", "_")
             )
    
    return dict(zip(list_columns, list_columns_new))

def renameDatasetColumns(df):
    list_columns = df.columns

    list_dict_to_rename = getDictToRenameDataFrame(list_columns)
    return df.rename(columns=list_dict_to_rename).drop(["unnamed:_22"], axis=1)

def hour_transform(n):
    if len(str(n)) == 4:
        return str(n)[0:2] + ":" + str(n)[2:] + ":00"
    elif len(str(n)) == 3:
        return "0" + str(n)[0:1] + ":" + str(n)[1:] + ":00"
    elif n == 0:
        return "00:00:00"

def create_datetime_feature(df):
    df["hora_medicao"] = df["hora_medicao"].apply(hour_transform)
    df["data_hora_str"] = df["data_medicao"] + " " + df["hora_medicao"]
    df["data_hora"] = pd.to_datetime(df["data_hora_str"])
    df["hora"] = df['data_hora'].dt.hour
    
    return df.drop(["data_hora_str", "data_medicao", "hora_medicao"], axis=1)

def create_split_date_features(df):
    df["dia"] = df["data_hora"].dt.day
    df["mes"] = df["data_hora"].dt.month
    df["ano"] = df["data_hora"].dt.year

    return df

def create_category(column, df):
    labels = ["A", "B", "C", "D"]
    classes = df.describe()[column][3:8].values

    if classes[1] == 0:
        classes[1] = classes[1]+0.1
        print("aqui")
    print(classes)
    
    return pd.cut(x = df[column],
         bins = classes,
         labels = labels,
         include_lowest = True)

def removeNulls(df, col):
    return df[df[col].notnull()]

def pre_processing(df):
    renameDatasetColumns(df)

def load(path):
    return pd.read_csv(path, sep=";", skiprows=10)

def get_perc_nulls(df):
    return (df.isnull().sum()/(len(df)))*100

# %% [markdown]
# ### Obtendo os dados
# Por uma qestão de recursos, não foi possivel carregar todas as estações em um dicionário, por exemplo. Sendo assim, o método `get_files` tem um parâmetro que determina a condição de "lazy", ou seja, eu carrego somente os paths dos arquivos e vou carregando na memória somente o que usarei. Além disso, podemos especificar a quantidade de arquivos através do parâmetro `n`.

# %%
dict_data = get_files(n=None)

# %%
print(dict_data.keys())
# Out:
# dict_keys(['A316', 'A419', 'A853', 'A372', 'A326', 'A225', 'A348', 'A207', 'A319', 'A430', 'A358', 'A440', 'A305', 'A337', 'A340', 'A204', 'B806', 'A825', 'A446', 'A338', 'A331', 'A872', 'A301', 'A350', 'A330', 'A823', 'A333', 'A322', 'A821', 'A828', 'A346', 'A318', 'A349', 'A336', 'A343', 'A441', 'A308', 'A220', 'A411', 'A313', 'A846', 'A855', 'A237', 'A820', 'A874', 'A450', 'A218', 'A405', 'A341', 'A444', 'A436', 'A811', 'A363', 'A352', 'A217', 'A351', 'A320', 'A239', 'A224', 'A449', 'A205', 'A873', 'A409', 'A221', 'A843', 'A304', 'A238', 'A812', 'A055', 'A317', 'A807', 'A357', 'A345', 'A133', 'A437', 'A310', 'A452', 'A818', 'A835', 'A203', 'A822', 'A424', 'A407', 'A365', 'A404', 'A354', 'A417', 'A455', 'A328', 'A377', 'A309', 'A438', 'A306', 'A849', 'A206', 'A359', 'A361', 'A842', 'A824', 'A307', 'A420', 'A054', 'A219', 'B803', 'A127', 'A826', 'A332', 'A375', 'A362', 'B804', 'A311', 'A414', 'A827', 'A223', 'A329', 'A423', 'A875', 'A344', 'A840', 'A819', 'A850', 'A222', 'A401', 'A324', 'A428', 'A312', 'A421', 'A335', 'A802', 'A881', 'A339', 'A315', 'A334', 'A876', 'A435', 'A427', 'A314', 'A364', 'A871', 'A302', 'A325', 'A370', 'A847', 'A360', 'A454', 'A410', 'A869', 'A347'])

# %% [markdown]
# ### Renomeando as colunas

# %%
df = renameDatasetColumns(load(dict_data["A223"][1]))

# %% [markdown]
# ### Showing info data

# %%
print(dict_data["A223"][0])
# Out:
# Nome: ALTO PARNAIBA
# Codigo Estacao: A223
# Latitude: -9.10833333
# Longitude: -45.93194443
# Altitude: 283.69
# Situacao: Operante
# Data Inicial: 2008-06-02
# Data Final: 2023-09-10
# Periodicidade da Medicao: Horaria

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133896 entries, 0 to 133895
# Data columns (total 22 columns):
#  #   Column                                              Non-Null Count   Dtype
# ---  ------                                              --------------   -----
#  0   data_medicao                                        133896 non-null  object
#  1   hora_medicao                                        133896 non-null  int64
#  2   precipitacao_total_horario_mm                       117338 non-null  float64
#  3   pressao_atmosferica_ao_nivel_da_estacao_horaria_mb  118324 non-null  float64
#  4   pressao_atmosferica_reduzida_nivel_do_mar_aut_mb    118314 non-null  float64
#  5   pressao_atmosferica_max_na_hora_ant_aut_mb          118229 non-null  float64
#  6   pressao_atmosferica_min_na_hora_ant_aut_mb          118229 non-null  float64
#  7   radiacao_global_kjm2                                118207 non-null  float64
#  8   temperatura_da_cpu_da_estacao_c                     118338 non-null  float64
#  9   temperatura_do_ar_bulbo_seco_horaria_c              118325 non-null  float64
#  10  temperatura_do_ponto_de_orvalho_c                   118325 non-null  float64
#  11  temperatura_maxima_na_hora_ant_aut_c                118229 non-null  float64
#  12  temperatura_minima_na_hora_ant_aut_c                118229 non-null  float64
#  13  temperatura_orvalho_max_na_hora_ant_aut_c           118228 non-null  float64
#  14  temperatura_orvalho_min_na_hora_ant_aut_c           118228 non-null  float64
#  15  tensao_da_bateria_da_estacao_v                      118336 non-null  float64
#  16  umidade_rel_max_na_hora_ant_aut_perc                118228 non-null  float64
#  17  umidade_rel_min_na_hora_ant_aut_perc                118223 non-null  float64
#  18  umidade_relativa_do_ar_horaria_perc                 118324 non-null  float64
#  19  vento_direcao_horaria_gr__gr                        88479 non-null   float64
#  20  vento_rajada_maxima_ms                              118173 non-null  float64
#  21  vento_velocidade_horaria_ms                         118305 non-null  float64
# dtypes: float64(20), int64(1), object(1)
# memory usage: 22.5+ MB

# %% [markdown]
# O dataset contém uma quantidade consderável de nulos, principalmente falando da coluna `vento_direcao_horaria_gr__gr`. Neste caso, vamos remover os nulos com base na característica teórica mais importante, a radiação. Mas antes, vamos só ver a porecntagem de nulos por coluna.

# %%
get_perc_nulls(df)
# Out:
# data_medicao                                           0.000000
# hora_medicao                                           0.000000
# precipitacao_total_horario_mm                         12.366314
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb    11.629922
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb      11.637390
# pressao_atmosferica_max_na_hora_ant_aut_mb            11.700872
# pressao_atmosferica_min_na_hora_ant_aut_mb            11.700872
# radiacao_global_kjm2                                  11.717303
# temperatura_da_cpu_da_estacao_c                       11.619466
# temperatura_do_ar_bulbo_seco_horaria_c                11.629175
# temperatura_do_ponto_de_orvalho_c                     11.629175
# temperatura_maxima_na_hora_ant_aut_c                  11.700872
# temperatura_minima_na_hora_ant_aut_c                  11.700872
# temperatura_orvalho_max_na_hora_ant_aut_c             11.701619
# temperatura_orvalho_min_na_hora_ant_aut_c             11.701619
# tensao_da_bateria_da_estacao_v                        11.620960
# umidade_rel_max_na_hora_ant_aut_perc                  11.701619
# umidade_rel_min_na_hora_ant_aut_perc                  11.705353
# umidade_relativa_do_ar_horaria_perc                   11.629922
# vento_direcao_horaria_gr__gr                          33.919609
# vento_rajada_maxima_ms                                11.742696
# vento_velocidade_horaria_ms                           11.644112
# dtype: float64

# %%
df_non_null = removeNulls(df, "radiacao_global_kjm2")

# %% [markdown]
# ### Configurando campos de data e hora.
# Como a coluna `data_medicao` e `hora_medicao` estão separadas e não são do tipo date/time, precisamos criar uma coluna que seja desse tipo.

# %%
df_non_null_dt = create_datetime_feature(df_non_null)
df_non_null_dt = create_split_date_features(df_non_null_dt)

# %% [markdown]
# ### Plot inicial dos dados

# %%
df_non_null_dt.head().T
# Out:
#                                                                      61  \
# precipitacao_total_horario_mm                                       0.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb                983.2
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb            1015.501837
# pressao_atmosferica_max_na_hora_ant_aut_mb                        983.4
# pressao_atmosferica_min_na_hora_ant_aut_mb                        983.2
# radiacao_global_kjm2                                           1991.735
# temperatura_da_cpu_da_estacao_c                                    28.0
# temperatura_do_ar_bulbo_seco_horaria_c                             28.4
# temperatura_do_ponto_de_orvalho_c                                  17.7
# temperatura_maxima_na_hora_ant_aut_c                               28.4
# temperatura_minima_na_hora_ant_aut_c                               23.9
# temperatura_orvalho_max_na_hora_ant_aut_c                          18.0
# temperatura_orvalho_min_na_hora_ant_aut_c                          15.7
# tensao_da_bateria_da_estacao_v                                     12.8
# umidade_rel_max_na_hora_ant_aut_perc                               61.0
# umidade_rel_min_na_hora_ant_aut_perc                               52.0
# umidade_relativa_do_ar_horaria_perc                                52.0
# vento_direcao_horaria_gr__gr                                      131.0
# vento_rajada_maxima_ms                                              3.1
# vento_velocidade_horaria_ms                                         1.1
# data_hora                                           2008-06-04 13:00:00
# hora                                                                 13
# dia                                                                   4
# mes                                                                   6
# ano                                                                2008
#
#                                                                      62  \
# precipitacao_total_horario_mm                                       0.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb                982.6
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb            1014.687477
# pressao_atmosferica_max_na_hora_ant_aut_mb                        983.2
# pressao_atmosferica_min_na_hora_ant_aut_mb                        982.6
# radiacao_global_kjm2                                           2759.175
# temperatura_da_cpu_da_estacao_c                                    31.0
# temperatura_do_ar_bulbo_seco_horaria_c                             30.2
# temperatura_do_ponto_de_orvalho_c                                  17.0
# temperatura_maxima_na_hora_ant_aut_c                               30.2
# temperatura_minima_na_hora_ant_aut_c                               28.2
# temperatura_orvalho_max_na_hora_ant_aut_c                          17.9
# temperatura_orvalho_min_na_hora_ant_aut_c                          16.4
# tensao_da_bateria_da_estacao_v                                     12.7
# umidade_rel_max_na_hora_ant_aut_perc                               53.0
# umidade_rel_min_na_hora_ant_aut_perc                               44.0
# umidade_relativa_do_ar_horaria_perc                                45.0
# vento_direcao_horaria_gr__gr                                      118.0
# vento_rajada_maxima_ms                                              8.1
# vento_velocidade_horaria_ms                                         3.4
# data_hora                                           2008-06-04 14:00:00
# hora                                                                 14
# dia                                                                   4
# mes                                                                   6
# ano                                                                2008
#
#                                                                      63  \
# precipitacao_total_horario_mm                                       0.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb                981.7
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb            1013.725903
# pressao_atmosferica_max_na_hora_ant_aut_mb                        982.6
# pressao_atmosferica_min_na_hora_ant_aut_mb                        981.7
# radiacao_global_kjm2                                           2590.988
# temperatura_da_cpu_da_estacao_c                                    32.0
# temperatura_do_ar_bulbo_seco_horaria_c                             30.5
# temperatura_do_ponto_de_orvalho_c                                  15.6
# temperatura_maxima_na_hora_ant_aut_c                               31.1
# temperatura_minima_na_hora_ant_aut_c                               29.1
# temperatura_orvalho_max_na_hora_ant_aut_c                          16.8
# temperatura_orvalho_min_na_hora_ant_aut_c                          14.9
# tensao_da_bateria_da_estacao_v                                     13.0
# umidade_rel_max_na_hora_ant_aut_perc                               46.0
# umidade_rel_min_na_hora_ant_aut_perc                               39.0
# umidade_relativa_do_ar_horaria_perc                                40.0
# vento_direcao_horaria_gr__gr                                      120.0
# vento_rajada_maxima_ms                                              9.2
# vento_velocidade_horaria_ms                                         3.6
# data_hora                                           2008-06-04 15:00:00
# hora                                                                 15
# dia                                                                   4
# mes                                                                   6
# ano                                                                2008
#
#                                                                      64  \
# precipitacao_total_horario_mm                                       0.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb                980.7
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb            1012.725431
# pressao_atmosferica_max_na_hora_ant_aut_mb                        981.7
# pressao_atmosferica_min_na_hora_ant_aut_mb                        980.6
# radiacao_global_kjm2                                           2690.375
# temperatura_da_cpu_da_estacao_c                                    34.0
# temperatura_do_ar_bulbo_seco_horaria_c                             30.2
# temperatura_do_ponto_de_orvalho_c                                  14.9
# temperatura_maxima_na_hora_ant_aut_c                               31.9
# temperatura_minima_na_hora_ant_aut_c                               30.1
# temperatura_orvalho_max_na_hora_ant_aut_c                          15.8
# temperatura_orvalho_min_na_hora_ant_aut_c                          14.2
# tensao_da_bateria_da_estacao_v                                     12.8
# umidade_rel_max_na_hora_ant_aut_perc                               41.0
# umidade_rel_min_na_hora_ant_aut_perc                               35.0
# umidade_relativa_do_ar_horaria_perc                                39.0
# vento_direcao_horaria_gr__gr                                      115.0
# vento_rajada_maxima_ms                                              7.7
# vento_velocidade_horaria_ms                                         3.7
# data_hora                                           2008-06-04 16:00:00
# hora                                                                 16
# dia                                                                   4
# mes                                                                   6
# ano                                                                2008
#
#                                                                      65
# precipitacao_total_horario_mm                                       0.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb                979.6
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb            1011.397782
# pressao_atmosferica_max_na_hora_ant_aut_mb                        980.7
# pressao_atmosferica_min_na_hora_ant_aut_mb                        979.6
# radiacao_global_kjm2                                           2498.412
# temperatura_da_cpu_da_estacao_c                                    35.0
# temperatura_do_ar_bulbo_seco_horaria_c                             32.0
# temperatura_do_ponto_de_orvalho_c                                  13.9
# temperatura_maxima_na_hora_ant_aut_c                               32.4
# temperatura_minima_na_hora_ant_aut_c                               30.2
# temperatura_orvalho_max_na_hora_ant_aut_c                          15.4
# temperatura_orvalho_min_na_hora_ant_aut_c                          13.2
# tensao_da_bateria_da_estacao_v                                     13.0
# umidade_rel_max_na_hora_ant_aut_perc                               40.0
# umidade_rel_min_na_hora_ant_aut_perc                               32.0
# umidade_relativa_do_ar_horaria_perc                                33.0
# vento_direcao_horaria_gr__gr                                      116.0
# vento_rajada_maxima_ms                                              7.7
# vento_velocidade_horaria_ms                                         2.3
# data_hora                                           2008-06-04 17:00:00
# hora                                                                 17
# dia                                                                   4
# mes                                                                   6
# ano                                                                2008

# %%
df = df_non_null_dt

# %% [markdown]
# ### Algumas estatísticas e Outliers
# Uma checagem rápida das estatísticas dos dados para detectar em um rimeiro momento a presença de outliers.

# %%
df.describe().T
# Out:
#                                                        count  \
# precipitacao_total_horario_mm                       117217.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb  118207.0
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb    118197.0
# pressao_atmosferica_max_na_hora_ant_aut_mb          118116.0
# pressao_atmosferica_min_na_hora_ant_aut_mb          118116.0
# radiacao_global_kjm2                                118207.0
# temperatura_da_cpu_da_estacao_c                     118207.0
# temperatura_do_ar_bulbo_seco_horaria_c              118207.0
# temperatura_do_ponto_de_orvalho_c                   118207.0
# temperatura_maxima_na_hora_ant_aut_c                118116.0
# temperatura_minima_na_hora_ant_aut_c                118116.0
# temperatura_orvalho_max_na_hora_ant_aut_c           118115.0
# temperatura_orvalho_min_na_hora_ant_aut_c           118115.0
# tensao_da_bateria_da_estacao_v                      118207.0
# umidade_rel_max_na_hora_ant_aut_perc                118115.0
# umidade_rel_min_na_hora_ant_aut_perc                118110.0
# umidade_relativa_do_ar_horaria_perc                 118206.0
# vento_direcao_horaria_gr__gr                         88479.0
# vento_rajada_maxima_ms                              118060.0
# vento_velocidade_horaria_ms                         118192.0
# data_hora                                             118207
# hora                                                118207.0
# dia                                                 118207.0
# mes                                                 118207.0
# ano                                                 118207.0
#
#                                                                              mean  \
# precipitacao_total_horario_mm                                            0.121063
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb                     979.333034
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb                      1011.732106
# pressao_atmosferica_max_na_hora_ant_aut_mb                             979.628828
# pressao_atmosferica_min_na_hora_ant_aut_mb                             979.047386
# radiacao_global_kjm2                                                   807.321589
# temperatura_da_cpu_da_estacao_c                                         27.887325
# temperatura_do_ar_bulbo_seco_horaria_c                                    26.4331
# temperatura_do_ponto_de_orvalho_c                                       18.001184
# temperatura_maxima_na_hora_ant_aut_c                                    27.194777
# temperatura_minima_na_hora_ant_aut_c                                    25.697437
# temperatura_orvalho_max_na_hora_ant_aut_c                                18.61322
# temperatura_orvalho_min_na_hora_ant_aut_c                               17.407247
# tensao_da_bateria_da_estacao_v                                          12.622137
# umidade_rel_max_na_hora_ant_aut_perc                                    68.576497
# umidade_rel_min_na_hora_ant_aut_perc                                    62.096461
# umidade_relativa_do_ar_horaria_perc                                     65.343756
# vento_direcao_horaria_gr__gr                                           153.212559
# vento_rajada_maxima_ms                                                   3.244266
# vento_velocidade_horaria_ms                                              0.943036
# data_hora                                           2015-07-01 13:52:06.667625216
# hora                                                                    11.598602
# dia                                                                     15.719441
# mes                                                                      6.532769
# ano                                                                   2014.996066
#
#                                                                     min  \
# precipitacao_total_horario_mm                                       0.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb                970.9
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb            1002.591188
# pressao_atmosferica_max_na_hora_ant_aut_mb                        971.1
# pressao_atmosferica_min_na_hora_ant_aut_mb                        970.7
# radiacao_global_kjm2                                              -7.14
# temperatura_da_cpu_da_estacao_c                                    14.0
# temperatura_do_ar_bulbo_seco_horaria_c                             12.7
# temperatura_do_ponto_de_orvalho_c                                   0.0
# temperatura_maxima_na_hora_ant_aut_c                               13.1
# temperatura_minima_na_hora_ant_aut_c                               12.4
# temperatura_orvalho_max_na_hora_ant_aut_c                           1.1
# temperatura_orvalho_min_na_hora_ant_aut_c                          -0.7
# tensao_da_bateria_da_estacao_v                                      5.9
# umidade_rel_max_na_hora_ant_aut_perc                               10.0
# umidade_rel_min_na_hora_ant_aut_perc                               10.0
# umidade_relativa_do_ar_horaria_perc                                10.0
# vento_direcao_horaria_gr__gr                                        1.0
# vento_rajada_maxima_ms                                              0.0
# vento_velocidade_horaria_ms                                         0.0
# data_hora                                           2008-06-04 13:00:00
# hora                                                                0.0
# dia                                                                 1.0
# mes                                                                 1.0
# ano                                                              2008.0
#
#                                                                     25%  \
# precipitacao_total_horario_mm                                       0.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb                977.7
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb            1009.950199
# pressao_atmosferica_max_na_hora_ant_aut_mb                        978.0
# pressao_atmosferica_min_na_hora_ant_aut_mb                        977.4
# radiacao_global_kjm2                                              -3.54
# temperatura_da_cpu_da_estacao_c                                    24.0
# temperatura_do_ar_bulbo_seco_horaria_c                             22.7
# temperatura_do_ponto_de_orvalho_c                                  15.0
# temperatura_maxima_na_hora_ant_aut_c                               23.1
# temperatura_minima_na_hora_ant_aut_c                               22.4
# temperatura_orvalho_max_na_hora_ant_aut_c                          15.7
# temperatura_orvalho_min_na_hora_ant_aut_c                          14.4
# tensao_da_bateria_da_estacao_v                                     12.3
# umidade_rel_max_na_hora_ant_aut_perc                               51.0
# umidade_rel_min_na_hora_ant_aut_perc                               41.0
# umidade_relativa_do_ar_horaria_perc                                46.0
# vento_direcao_horaria_gr__gr                                       80.0
# vento_rajada_maxima_ms                                              1.2
# vento_velocidade_horaria_ms                                         0.0
# data_hora                                           2011-12-07 20:30:00
# hora                                                                6.0
# dia                                                                 8.0
# mes                                                                 4.0
# ano                                                              2011.0
#
#                                                                     50%  \
# precipitacao_total_horario_mm                                       0.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb                979.3
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb            1011.726332
# pressao_atmosferica_max_na_hora_ant_aut_mb                        979.6
# pressao_atmosferica_min_na_hora_ant_aut_mb                        979.0
# radiacao_global_kjm2                                             59.869
# temperatura_da_cpu_da_estacao_c                                    27.0
# temperatura_do_ar_bulbo_seco_horaria_c                             25.4
# temperatura_do_ponto_de_orvalho_c                                  19.4
# temperatura_maxima_na_hora_ant_aut_c                               26.3
# temperatura_minima_na_hora_ant_aut_c                               24.7
# temperatura_orvalho_max_na_hora_ant_aut_c                          20.0
# temperatura_orvalho_min_na_hora_ant_aut_c                          18.7
# tensao_da_bateria_da_estacao_v                                     12.4
# umidade_rel_max_na_hora_ant_aut_perc                               75.0
# umidade_rel_min_na_hora_ant_aut_perc                               65.0
# umidade_relativa_do_ar_horaria_perc                                70.0
# vento_direcao_horaria_gr__gr                                      139.0
# vento_rajada_maxima_ms                                              2.4
# vento_velocidade_horaria_ms                                         0.5
# data_hora                                           2015-06-13 02:00:00
# hora                                                               12.0
# dia                                                                16.0
# mes                                                                 7.0
# ano                                                              2015.0
#
#                                                                     75%  \
# precipitacao_total_horario_mm                                       0.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb                980.9
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb            1013.544327
# pressao_atmosferica_max_na_hora_ant_aut_mb                        981.2
# pressao_atmosferica_min_na_hora_ant_aut_mb                        980.7
# radiacao_global_kjm2                                           1637.746
# temperatura_da_cpu_da_estacao_c                                    32.0
# temperatura_do_ar_bulbo_seco_horaria_c                             30.5
# temperatura_do_ponto_de_orvalho_c                                  21.4
# temperatura_maxima_na_hora_ant_aut_c                               31.6
# temperatura_minima_na_hora_ant_aut_c                               29.4
# temperatura_orvalho_max_na_hora_ant_aut_c                          21.8
# temperatura_orvalho_min_na_hora_ant_aut_c                          20.9
# tensao_da_bateria_da_estacao_v                                     13.0
# umidade_rel_max_na_hora_ant_aut_perc                               89.0
# umidade_rel_min_na_hora_ant_aut_perc                               85.0
# umidade_relativa_do_ar_horaria_perc                                87.0
# vento_direcao_horaria_gr__gr                                      203.0
# vento_rajada_maxima_ms                                              5.1
# vento_velocidade_horaria_ms                                         1.6
# data_hora                                           2018-10-26 10:30:00
# hora                                                               18.0
# dia                                                                23.0
# mes                                                                 9.0
# ano                                                              2018.0
#
#                                                                     max  \
# precipitacao_total_horario_mm                                      74.2
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb                989.0
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb            1021.902662
# pressao_atmosferica_max_na_hora_ant_aut_mb                        989.1
# pressao_atmosferica_min_na_hora_ant_aut_mb                        988.9
# radiacao_global_kjm2                                            4248.42
# temperatura_da_cpu_da_estacao_c                                    43.0
# temperatura_do_ar_bulbo_seco_horaria_c                             40.7
# temperatura_do_ponto_de_orvalho_c                                  25.7
# temperatura_maxima_na_hora_ant_aut_c                               41.1
# temperatura_minima_na_hora_ant_aut_c                               39.8
# temperatura_orvalho_max_na_hora_ant_aut_c                          26.3
# temperatura_orvalho_min_na_hora_ant_aut_c                          24.9
# tensao_da_bateria_da_estacao_v                                     14.3
# umidade_rel_max_na_hora_ant_aut_perc                               97.0
# umidade_rel_min_na_hora_ant_aut_perc                               97.0
# umidade_relativa_do_ar_horaria_perc                                97.0
# vento_direcao_horaria_gr__gr                                      360.0
# vento_rajada_maxima_ms                                             22.5
# vento_velocidade_horaria_ms                                         9.7
# data_hora                                           2023-09-10 23:00:00
# hora                                                               23.0
# dia                                                                31.0
# mes                                                                12.0
# ano                                                              2023.0
#
#                                                             std
# precipitacao_total_horario_mm                          1.208395
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb     2.377312
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb       2.658985
# pressao_atmosferica_max_na_hora_ant_aut_mb             2.356236
# pressao_atmosferica_min_na_hora_ant_aut_mb             2.375499
# radiacao_global_kjm2                                1083.091308
# temperatura_da_cpu_da_estacao_c                        5.539456
# temperatura_do_ar_bulbo_seco_horaria_c                 4.998975
# temperatura_do_ponto_de_orvalho_c                      4.093543
# temperatura_maxima_na_hora_ant_aut_c                   5.167875
# temperatura_minima_na_hora_ant_aut_c                   4.794372
# temperatura_orvalho_max_na_hora_ant_aut_c              3.983192
# temperatura_orvalho_min_na_hora_ant_aut_c               4.21058
# tensao_da_bateria_da_estacao_v                         0.445917
# umidade_rel_max_na_hora_ant_aut_perc                   22.79767
# umidade_rel_min_na_hora_ant_aut_perc                  23.990384
# umidade_relativa_do_ar_horaria_perc                   23.516418
# vento_direcao_horaria_gr__gr                          96.903363
# vento_rajada_maxima_ms                                 2.635168
# vento_velocidade_horaria_ms                            1.119615
# data_hora                                                   NaN
# hora                                                   6.893098
# dia                                                     8.82038
# mes                                                    3.347817
# ano                                                    4.196215

# %% [markdown]
# #### Radiação
# O desvio padrão da radiação está muito alto em relação a média. Vamos fazer algumas análises e tentar chegar numa conclusão.

# %% [markdown]
# ##### Percentil

# %%
for i in range(0, 101):
    value_str = str(i)

    if len(value_str) == 1:
        value_str = "0.0"+value_str
    
    elif len(value_str) == 2:
        value_str = "0."+value_str
    else:
        value_str = "1.0"
    
    double_value = float(value_str) 
    print(value_str, df["radiacao_global_kjm2"].quantile(double_value))
# Out:
# 0.00 -7.14
# 0.01 -3.54
# 0.02 -3.54
# 0.03 -3.54
# 0.04 -3.54
# 0.05 -3.54
# 0.06 -3.54
# 0.07 -3.54
# 0.08 -3.54
# 0.09 -3.54
# 0.10 -3.54
# 0.11 -3.54
# 0.12 -3.54
# 0.13 -3.54
# 0.14 -3.54
# 0.15 -3.54
# 0.16 -3.54
# 0.17 -3.54
# 0.18 -3.54
# 0.19 -3.54
# 0.20 -3.54
# 0.21 -3.54
# 0.22 -3.54
# 0.23 -3.54
# 0.24 -3.54
# 0.25 -3.54
# 0.26 -3.538
# 0.27 -3.536
# 0.28 -3.533
# 0.29 -3.528
# 0.30 -3.517
# 0.31 -3.501
# 0.32 -3.477
# 0.33 -3.446
# 0.34 -3.408
# 0.35 -3.358
# 0.36 -3.301
# 0.37 -3.23
# 0.38 -3.151
# 0.39 -3.049
# 0.40 -2.926
# 0.41 -2.789
# 0.42 -2.623
# 0.43 -2.439
# 0.44 -2.21
# 0.45 -1.873
# 0.46 -1.248
# 0.47 1.3620999999999985
# 0.48 10.788599999999947
# 0.49 29.84422000000003
# 0.50 59.869
# 0.51 86.58449999999993
# 0.52 109.98772000000001
# 0.53 132.74668
# 0.54 158.94204000000025
# 0.55 191.06370000000004
# 0.56 226.91136
# 0.57 274.65745999999984
# 0.58 345.1456799999999
# 0.59 422.56139999999994
# 0.60 504.582999999999
# 0.61 588.0769600000008
# 0.62 674.33836
# 0.63 739.06134
# 0.64 800.5677199999998
# 0.65 858.5394000000008
# 0.66 918.2296400000001
# 0.67 983.5760600000002
# 0.68 1059.1596800000002
# 0.69 1151.0354199999997
# 0.70 1263.2935999999997
# 0.71 1359.3544999999992
# 0.72 1440.8166799999995
# 0.73 1509.2000800000005
# 0.74 1571.18004
# 0.75 1637.746
# 0.76 1709.52152
# 0.77 1789.7870999999998
# 0.78 1873.86676
# 0.79 1954.9528200000007
# 0.80 2025.4204000000002
# 0.81 2093.0261
# 0.82 2158.49804
# 0.83 2213.28984
# 0.84 2273.728
# 0.85 2333.1162999999992
# 0.86 2387.67108
# 0.87 2450.35698
# 0.88 2512.77224
# 0.89 2571.412
# 0.90 2627.799000000001
# 0.91 2684.2474400000006
# 0.92 2740.9664000000002
# 0.93 2796.8815
# 0.94 2859.5678
# 0.95 2935.2655999999993
# 0.96 3020.1489599999995
# 0.97 3141.3013799999985
# 0.98 3287.8625600000005
# 0.99 3461.22464
# 1.0 4248.42

# %% [markdown]
# Como vimos, mudanças significtiva nos dados ocorrem a partir do 47th percentil. Vamos agora ordenar para ver se o maior valor está muito diferentes dos próximos.

# %%
df.sort_values(by="radiacao_global_kjm2", ascending=False)["radiacao_global_kjm2"].head(10)
# Out:
# 23319     4248.420
# 23465     4238.149
# 110584    4166.611
# 110919    4138.059
# 67408     4085.976
# 67312     4037.309
# 50488     4033.217
# 75759     4030.560
# 128824    4010.973
# 92512     3996.234
# Name: radiacao_global_kjm2, dtype: float64

# %%
df.sort_values(by="radiacao_global_kjm2", ascending=True)["radiacao_global_kjm2"].head(10)
# Out:
# 53237    -7.14
# 131495   -6.90
# 61610    -3.54
# 57583    -3.54
# 57599    -3.54
# 57600    -3.54
# 57601    -3.54
# 57602    -3.54
# 57603    -3.54
# 57604    -3.54
# Name: radiacao_global_kjm2, dtype: float64

# %% [markdown]
# Aparentemente, não há outliers, vamos calcular o z-score para essa coluna: `Z = (X−µ) ÷ σ`

# %%
df[["radiacao_global_kjm2"]].apply(zscore).sort_values(by="radiacao_global_kjm2", ascending=False)
# Out:
#         radiacao_global_kjm2
# 23319               3.177122
# 23465               3.167639
# 110584              3.101589
# 110919              3.075227
# 67408               3.027139
# ...                      ...
# 66123              -0.748658
# 66124              -0.748658
# 133895             -0.748658
# 131495             -0.751760
# 53237              -0.751982
#
# [118207 rows x 1 columns]

# %% [markdown]
# O z-score não mostrou nada muito atipico. Vamos plotar o histograma.

# %%
df["radiacao_global_kjm2"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[df["radiacao_global_kjm2"]>0]["radiacao_global_kjm2"].count()
# Out:
# 62964

# %%
df[df["radiacao_global_kjm2"]>0]["radiacao_global_kjm2"].describe()
# Out:
# count    62964.000000
# mean      1518.535293
# std       1058.289102
# min          0.001000
# 25%        508.691500
# 50%       1532.214000
# 75%       2430.265250
# max       4248.420000
# Name: radiacao_global_kjm2, dtype: float64

# %%
df[df["radiacao_global_kjm2"]>0]["radiacao_global_kjm2"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Apesar do desbalanceamento dos dados, não se pode afirmar que a radiação tenha outliers. Portanto, não removeremos nenhum registro. Entretanto, podemos remover posteriormente apenas para ver o comportamento dos dados.

# %%
# df = df[df["radiacao_global_kjm2"]>0]

# %% [markdown]
# #### Vento
# Aparentemente, a variável do vento contém alguns dados desbalanceados, como podemos ver aqui no histograma

# %%
sns.set_theme(rc={'figure.figsize':(8.7,5.27)})
df["vento_rajada_maxima_ms"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[df["vento_rajada_maxima_ms"] > 15]["vento_rajada_maxima_ms"].count()
# Out:
# 51

# %%
df = df[df["vento_rajada_maxima_ms"] <=15]

# %% [markdown]
# ### Removendo colunas
# A coluna `precipitacao_total_horario_mm` tem muitos zeros ou nulos, portanto, iremos remove-la.

# %%
df["precipitacao_total_horario_mm"].value_counts()
# Out:
# precipitacao_total_horario_mm
# 0.0     111824
# 0.2       1632
# 0.4        518
# 0.6        394
# 0.8        263
#          ...
# 24.4         1
# 33.4         1
# 28.0         1
# 32.2         1
# 19.2         1
# Name: count, Length: 163, dtype: int64

# %%
df["precipitacao_total_horario_mm"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
without_relevance = ["temperatura_do_ponto_de_orvalho_c",
                 "temperatura_orvalho_max_na_hora_ant_aut_c",
                 "temperatura_orvalho_min_na_hora_ant_aut_c",
                 "tensao_da_bateria_da_estacao_v",
                 "vento_direcao_horaria_gr__gr",
                 "vento_velocidade_horaria_ms"]

many_nulls_zeros = ["precipitacao_total_horario_mm"]

without_relevance.extend(many_nulls_zeros)

df = df.drop(without_relevance, axis=1)

# %% [markdown]
# ### Feature engineering
# Algumas colunas possuem comportamento similar. Portanto, podemos mescla-las em uma só.

# %% [markdown]
# #### Atmo Press

# %%
join_press = [
            "pressao_atmosferica_ao_nivel_da_estacao_horaria_mb", 
            "pressao_atmosferica_reduzida_nivel_do_mar_aut_mb",
            "pressao_atmosferica_max_na_hora_ant_aut_mb",
            "pressao_atmosferica_min_na_hora_ant_aut_mb"
       ]
df[join_press].describe().T
# Out:
#                                                        count         mean  \
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb  118009.0   979.333186
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb    117999.0  1011.732370
# pressao_atmosferica_max_na_hora_ant_aut_mb          118009.0   979.628951
# pressao_atmosferica_min_na_hora_ant_aut_mb          118009.0   979.047950
#
#                                                          std          min  \
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb  2.377600   970.900000
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb    2.659490  1002.591188
# pressao_atmosferica_max_na_hora_ant_aut_mb          2.356273   971.100000
# pressao_atmosferica_min_na_hora_ant_aut_mb          2.375214   970.700000
#
#                                                             25%          50%  \
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb   977.700000   979.300000
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb    1009.950199  1011.726332
# pressao_atmosferica_max_na_hora_ant_aut_mb           978.000000   979.600000
# pressao_atmosferica_min_na_hora_ant_aut_mb           977.400000   979.000000
#
#                                                             75%          max
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb   980.900000   989.000000
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb    1013.544741  1021.902662
# pressao_atmosferica_max_na_hora_ant_aut_mb           981.200000   989.100000
# pressao_atmosferica_min_na_hora_ant_aut_mb           980.700000   988.900000

# %%
df_local =  df[join_press]
df["press_atmo"] = df_local.mean(axis=1)
df = df.drop(join_press, axis=1)

# %% [markdown]
# #### Temperature

# %%
mean_temp = [
        "temperatura_do_ar_bulbo_seco_horaria_c",
        "temperatura_da_cpu_da_estacao_c", 
        "temperatura_maxima_na_hora_ant_aut_c",
        "temperatura_minima_na_hora_ant_aut_c"]

df[mean_temp].describe().T
# Out:
#                                            count       mean       std   min  \
# temperatura_do_ar_bulbo_seco_horaria_c  118009.0  26.432190  5.000648  12.7
# temperatura_da_cpu_da_estacao_c         118009.0  27.885170  5.541577  14.0
# temperatura_maxima_na_hora_ant_aut_c    118009.0  27.192986  5.168664  13.1
# temperatura_minima_na_hora_ant_aut_c    118009.0  25.698362  4.795188  12.4
#
#                                          25%   50%   75%   max
# temperatura_do_ar_bulbo_seco_horaria_c  22.7  25.4  30.5  40.7
# temperatura_da_cpu_da_estacao_c         24.0  27.0  32.0  43.0
# temperatura_maxima_na_hora_ant_aut_c    23.1  26.3  31.6  41.1
# temperatura_minima_na_hora_ant_aut_c    22.4  24.7  29.4  39.8

# %%
df_local =  df[mean_temp]
df["temperature"] = df_local.mean(axis=1)
df = df.drop(mean_temp, axis=1)

# %% [markdown]
# #### Humidity

# %%
mean_humidity = ["umidade_rel_max_na_hora_ant_aut_perc",
            "umidade_rel_min_na_hora_ant_aut_perc",
            "umidade_relativa_do_ar_horaria_perc"]

df[mean_humidity].describe().T
# Out:
#                                          count       mean        std   min  \
# umidade_rel_max_na_hora_ant_aut_perc  118009.0  68.568440  22.801473  10.0
# umidade_rel_min_na_hora_ant_aut_perc  118004.0  62.098675  23.996128  10.0
# umidade_relativa_do_ar_horaria_perc   118008.0  65.337062  23.525440  10.0
#
#                                        25%   50%   75%   max
# umidade_rel_max_na_hora_ant_aut_perc  51.0  75.0  89.0  97.0
# umidade_rel_min_na_hora_ant_aut_perc  41.0  65.0  85.0  97.0
# umidade_relativa_do_ar_horaria_perc   46.0  70.0  87.0  97.0

# %%
df_local =  df[mean_humidity]
df["humidity"] = df_local.mean(axis=1)
df = df.drop(mean_humidity, axis=1)

# %%
df.head()
# Out:
#     radiacao_global_kjm2  vento_rajada_maxima_ms           data_hora  hora  \
# 61              1991.735                     3.1 2008-06-04 13:00:00    13
# 62              2759.175                     8.1 2008-06-04 14:00:00    14
# 63              2590.988                     9.2 2008-06-04 15:00:00    15
# 64              2690.375                     7.7 2008-06-04 16:00:00    16
# 65              2498.412                     7.7 2008-06-04 17:00:00    17
#
#     dia  mes   ano  press_atmo  temperature   humidity
# 61    4    6  2008  991.325459       27.175  55.000000
# 62    4    6  2008  990.771869       29.900  47.333333
# 63    4    6  2008  989.931476       30.675  41.666667
# 64    4    6  2008  988.931358       31.550  38.333333
# 65    4    6  2008  987.824446       32.400  35.000000

# %% [markdown]
# ### Analise com datas
# Aqui iremos plotar a radiação por data

# %% [markdown]
# #### Ano

# %%
df_year = df[["ano", "radiacao_global_kjm2"]].groupby(['ano']).mean().reset_index()

# %% [markdown]
# #### Média e desvio
# Apenas para garantir que não temos uma discrepância entre média e desvio, vamos exibir por ano.

# %%
df[["ano", "radiacao_global_kjm2"]].groupby(['ano'])\
['radiacao_global_kjm2'].agg(['mean','std'])
# Out:
#              mean          std
# ano
# 2008   812.067214  1100.783780
# 2009   738.106375  1030.641014
# 2010   810.287032  1095.976715
# 2011   769.381774  1039.729977
# 2012   761.294305  1043.014028
# 2013   794.843625  1096.904261
# 2014   812.079230  1108.686651
# 2015   775.803668  1067.051429
# 2016   818.925024  1115.560545
# 2017   779.606667  1067.592495
# 2018   816.739132  1068.886111
# 2019   979.435454  1116.264617
# 2020   797.601386  1093.056989
# 2021   735.795710  1008.149781
# 2022  1096.401884  1266.160824
# 2023   864.263035  1114.558845

# %%
sns.lineplot(data=df_year, x=df_year["ano"], y=df_year["radiacao_global_kjm2"])
# Out:
# <Axes: xlabel='ano', ylabel='radiacao_global_kjm2'>

# %% [markdown]
# #### Mes

# %%
df_month = df[["mes", "radiacao_global_kjm2"]].groupby(['mes']).mean().reset_index()

# %%
sns.lineplot(data=df_month, x=df_month["mes"], y=df_month["radiacao_global_kjm2"])
# Out:
# <Axes: xlabel='mes', ylabel='radiacao_global_kjm2'>

# %% [markdown]
# #### Hora

# %%
df_hour = df[["hora", "radiacao_global_kjm2"]].groupby(['hora']).mean().reset_index()

# %%
sns.lineplot(data=df_hour, x=df_hour["hora"], y=df_hour["radiacao_global_kjm2"])
# Out:
# <Axes: xlabel='hora', ylabel='radiacao_global_kjm2'>

# %% [markdown]
# #### Hora com o vento como `hue`

# %%
df_hour_wind = df[[
    "hora", 
    "radiacao_global_kjm2", 
    "vento_rajada_maxima_ms"]]\
.fillna(0)

df_hour_wind["wind_catg"] = create_category("vento_rajada_maxima_ms", df_hour_wind)
# Out:
# [ 0.   1.2  2.4  5.1 15. ]

# %%
sns.lineplot(data=df_hour_wind, x=df_hour_wind["hora"], y=df_hour_wind["radiacao_global_kjm2"], hue=df_hour_wind["wind_catg"])
# Out:
# <Axes: xlabel='hora', ylabel='radiacao_global_kjm2'>

# %% [markdown]
# #### Hora com a pressão atmo. como `hue`

# %%
df_hour_press = df[[
    "hora", 
    "radiacao_global_kjm2", 
    "press_atmo"]]\
.fillna(0)

df_hour_press["press_catg"] = create_category("press_atmo", df_hour_press)
# Out:
# [978.63333333 985.7720005  987.401105   989.074538   997.12739275]

# %%
sns.lineplot(data=df_hour_press, x=df_hour_press["hora"], y=df_hour_press["radiacao_global_kjm2"], hue=df_hour_press["press_catg"])
# Out:
# <Axes: xlabel='hora', ylabel='radiacao_global_kjm2'>

# %% [markdown]
# #### Hora com a temperatura como `hue`

# %%
df_temp = df[[
    "hora", 
    "radiacao_global_kjm2", 
    "temperature"]]\
.fillna(0)

df_temp["temp_catg"] = create_category("temperature", df_temp)
# Out:
# [13.1   23.025 25.8   30.975 41.1  ]

# %%
sns.lineplot(data=df_temp, x=df_temp["hora"], y=df_temp["radiacao_global_kjm2"], hue=df_temp["temp_catg"])
# Out:
# <Axes: xlabel='hora', ylabel='radiacao_global_kjm2'>

# %% [markdown]
# #### Hora com a umidade como `hue`

# %%
df_temp = df[[
    "hora", 
    "radiacao_global_kjm2", 
    "humidity"]]\
.fillna(0)

df_temp["hum_catg"] = create_category("humidity", df_temp)
# Out:
# [10.         46.33333333 70.         87.         97.        ]

# %%
sns.lineplot(data=df_temp, x=df_temp["hora"], y=df_temp["radiacao_global_kjm2"], hue=df_temp["hum_catg"])
# Out:
# <Axes: xlabel='hora', ylabel='radiacao_global_kjm2'>

# %% [markdown]
# #### Relação linear entre radiação e vento

# %%
sns.lineplot(data=df, x=df["vento_rajada_maxima_ms"], y=df["radiacao_global_kjm2"])
# Out:
# <Axes: xlabel='vento_rajada_maxima_ms', ylabel='radiacao_global_kjm2'>

# %%
sns.lineplot(data=df, x=df["humidity"], y=df["radiacao_global_kjm2"])
# Out:
# <Axes: xlabel='humidity', ylabel='radiacao_global_kjm2'>

# %% [markdown]
# ### Conclusões
#
# #### Desbalanceamento
# O dataset possui uma quantidade razoável de nulos, quando falamos da coluna "alvo" radiação, que fica em torno de \~17%. Como não chega a ser um valor expressivo, podemos simplesmente remover os nulos dessa coluna. Em seguida, analisamos as estatisticas dos dados, como média, desvio padrão e quartis. O que foi percebido é um valor alto do desvio em relação a média, podendo indicar a presença de outliers. Entretanto, o dataset na verdade possui dados desbalanceados, tendo muitos valores negativos (~42%) na mesma faixa de valores, o que pode comppromenter uma futura previsão. Aqui podemos tratar esse desbalanceamento com algumas técnicas, como o undersampling, por exemplo. Iremos remover posteriormente, apenas para checar o comportamento dos dados quando plotamos.
#
# Ainda falando de dados desbalanceados, temos também a categoria "vento", que contém um numero pequeno de registros acima do valor 15. Portanto, para fins de previsão, podemos remove-los.
#
# Sobre a coluna de precipitação, temos valores zerados ou nulos quase em sua totalidade. Portanto, iremos remove-la do dataset.
#
# #### Feature Engineering
#
# No dataset, existem colunas que representam o mesmo conceito, e possuem medidas estatisticas (media, desvio) semelhantes. Portanto, aplicamos alguns métodos para "juntarmos" essas colunas semelhantes em uma só, como o caso das colunas de pressão atmosférica, umidade e temperatura.
#
#
# #### Analise com datas
#
# Para termos ma visão geral falando de séries temporais, agregamos os dados por ano, mes e horário, para tentar enxergar algum padrão.
#
# ##### Por ano
# Agregando os dados por ano, notou-se um comportamento incomun entre ~2008-2020, onde temos niveis baixos de radiação média ( ~935) em relação ao niveis médios a partir de 2020 ( ~1871). Não foi encontrado um motivo particular para esse comportamento.
#
# ##### Por mes
# Construindo um gráfico com dados agregados por mes, não houve nenhum ponto atípico. Os dados mostram uma maior incidência de radiação no início do ano (verão), com uma queda acentuada assim que deslocamos a coluna temporal até o meio do ano (outuno-inverno), com novo aumento da radiação assim que se aproxima do final do ano (primavera-verão).
#
# ##### Por hora
# Assim como o plot por mês, não houve nenhum comportamento atípico ao esperado, tendo a faixa ~10h-17h a maior incidência de radição do dia, caindo bruscamente a partir das 20h.
#
# ##### Valores horários por outra colunas
# Nessa análise, decidimos isolar as observações horárias por categorias (A, B, C e D) dentro de algumas colunas. Ou seja, utilizamos os quartis dessas colunas e categorizamos os valores. Ex: temperatura categoria A: de 0 a 15, categoria B: de 15 a 25, e assim por diante. As seguintes colunas foram utilzadas:
#
# - **Vento**: Percebemos uma ligeira relação diretamente proporcional entre ventos fortes e maiores niveis de radiação, porém nada relevante.
# - **Pressão atmosférica**: aqui tivemos um aumento dessa relação entre uma categoria esecifica (baixa pressão atmosférica) e o nivel de radiação solar.
# - **Temperatura**: no caso da temperatura, não houve comportamento ineserado, prevaelecendo as altas temperaturas com incidência da radiação.
# - **Umidade**: da mesma forma que a temperatura, também não houve nada diferente do previsto, com as baixas taxas de umidade tendo relação forte com altos valores de radiação solar.
#
# ##### Relação linear
# Como ultima análise, decidimos verificar se existe uma relação linear entre alguma coluna e os valores de radiação. Como escolha, tivemos um resultado interessante utilzando o vento novamente. O gráfico mostra que o pico de radiação é atingido quando a rajada máxima de vento fica entre 8-10 m/s, com queda acentuada ao ultrapassar esses valores.
