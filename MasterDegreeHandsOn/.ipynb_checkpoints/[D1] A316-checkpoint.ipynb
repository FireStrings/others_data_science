# %% [markdown]
# # Definições
# Esse notebook irá analisar dados da estação A316, na cidade de Caiacó, no Rio Grande do Norte, de 2007 a 2023. O propósito aqui é realizar o EDA dos dados e, como output, obter alguams conclusões.
#
# ### Possíveis análises:
# - Medir o nivel de radiação por ano, mes e horário do dia;
# - Confirmar se há relação entre as categorias criadas (hue) com a radiação;
# - Verificar estatísticas básicas (quantidades de nulls, media, desvio padrão, etc);
# - Remoção de colunas desnecessárias;
# - Feature engineering (juntar dois campos, criar campos category, etc)
# - Remoção de Outliers

# %% [markdown]
# ### Import das bibliotecas

# %%
import numpy as np
import seaborn as sns
import pandas as pd
from scipy.special import expit
from scipy.stats import zscore
from pandas.errors import SettingWithCopyWarning
import os
from os import listdir
from os import system

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)
warnings.simplefilter(action='ignore', category=SettingWithCopyWarning)


sns.set_theme(rc={'figure.figsize':(11.7,8.27)})

# %% [markdown]
# ### Métodos auxiliares

# %%
def getSigmoid():
    arr = np.arange(0, 1, 0.02)
    np.hstack(np.vstack(arr))
    def sigmoid(x):
        return 1/(1+expit(-x))
    
    sigmoid(arr)
    sns.scatterplot(x=arr, y=sigmoid(arr))

def get_files(n=1, lazy=True):
    cwd = os.getcwd()
    
    dict_data = {}
    list_files = [x for x in listdir(cwd + "/data/estacoes_solares/BDM_INMET/") if ".csv" in x]

    if n:
        _range = list_files[0:n]
    else:
        _range = list_files
    
    for i in _range:
        # print("Processando arquivo " + i)
        
        code = i.split("_")[1]
        head = os.popen("head -10 data/estacoes_solares/BDM_INMET/" + i).read()

        if lazy:
            data = "data/estacoes_solares/BDM_INMET/"+i
        else:
            data = pd.read_csv("data/estacoes_solares/BDM_INMET/"+i, sep=";", skiprows=10)
        
        dict_data[code] = [head, data]

    return dict_data

def getDictToRenameDataFrame(list_columns):
    list_columns_new = []
    for i in list_columns: 
        list_columns_new.append(str
              .lower(i)
              .replace(" ", "_")
              . replace("(", "_")
              .replace(")", "")
              .replace("/", "")
              .replace("²", "2")
              .replace("°", "")
              .replace("%", "perc")
              .replace("._", "_")
              .replace(".", "_")
              .replace("__", "_")
              .replace("_-_", "_")
              .replace(",_", "_")
             )
    
    return dict(zip(list_columns, list_columns_new))

def renameDatasetColumns(df):
    list_columns = df.columns

    list_dict_to_rename = getDictToRenameDataFrame(list_columns)
    return df.rename(columns=list_dict_to_rename).drop(["unnamed:_22"], axis=1)

def hour_transform(n):
    if len(str(n)) == 4:
        return str(n)[0:2] + ":" + str(n)[2:] + ":00"
    elif len(str(n)) == 3:
        return "0" + str(n)[0:1] + ":" + str(n)[1:] + ":00"
    elif n == 0:
        return "00:00:00"

def create_datetime_feature(df):
    df["hora_medicao"] = df["hora_medicao"].apply(hour_transform)
    df["data_hora_str"] = df["data_medicao"] + " " + df["hora_medicao"]
    df["data_hora"] = pd.to_datetime(df["data_hora_str"])
    df["hora"] = df['data_hora'].dt.hour
    
    return df.drop(["data_hora_str", "data_medicao", "hora_medicao"], axis=1)

def create_split_date_features(df):
    df["dia"] = df["data_hora"].dt.day
    df["mes"] = df["data_hora"].dt.month
    df["ano"] = df["data_hora"].dt.year

    return df

def create_category(column, df):
    labels = ["A", "B", "C", "D"]
    classes = df.describe()[column][3:8].values

    if classes[1] == 0:
        classes[1] = classes[1]+0.1
        print("aqui")
    print(classes)
    
    return pd.cut(x = df[column],
         bins = classes,
         labels = labels,
         include_lowest = True)

def removeNulls(df, col):
    return df[df[col].notnull()]

def pre_processing(df):
    renameDatasetColumns(df)

def load(path):
    return pd.read_csv(path, sep=";", skiprows=10)

def get_perc_nulls(df):
    return (df.isnull().sum()/(len(df)))*100

# %% [markdown]
# ### Obtendo os dados
# Por uma qestão de recursos, não foi possivel carregar todas as estações em um dicionário, por exemplo. Sendo assim, o método `get_files` tem um parâmetro que determina a condição de "lazy", ou seja, eu carrego somente os paths dos arquivos e vou carregando na memória somente o que usarei. Além disso, podemos especificar a quantidade de arquivos através do parâmetro `n`.

# %%
dict_data = get_files(n=None)

# %%
print(dict_data.keys())
# Out:
# dict_keys(['A316', 'A419', 'A853', 'A372', 'A326', 'A225', 'A348', 'A207', 'A319', 'A430', 'A358', 'A440', 'A305', 'A337', 'A340', 'A204', 'B806', 'A825', 'A446', 'A338', 'A331', 'A872', 'A301', 'A350', 'A330', 'A823', 'A333', 'A322', 'A821', 'A828', 'A346', 'A318', 'A349', 'A336', 'A343', 'A441', 'A308', 'A220', 'A411', 'A313', 'A846', 'A855', 'A237', 'A820', 'A874', 'A450', 'A218', 'A405', 'A341', 'A444', 'A436', 'A811', 'A363', 'A352', 'A217', 'A351', 'A320', 'A239', 'A224', 'A449', 'A205', 'A873', 'A409', 'A221', 'A843', 'A304', 'A238', 'A812', 'A055', 'A317', 'A807', 'A357', 'A345', 'A133', 'A437', 'A310', 'A452', 'A818', 'A835', 'A203', 'A822', 'A424', 'A407', 'A365', 'A404', 'A354', 'A417', 'A455', 'A328', 'A377', 'A309', 'A438', 'A306', 'A849', 'A206', 'A359', 'A361', 'A842', 'A824', 'A307', 'A420', 'A054', 'A219', 'B803', 'A127', 'A826', 'A332', 'A375', 'A362', 'B804', 'A311', 'A414', 'A827', 'A223', 'A329', 'A423', 'A875', 'A344', 'A840', 'A819', 'A850', 'A222', 'A401', 'A324', 'A428', 'A312', 'A421', 'A335', 'A802', 'A881', 'A339', 'A315', 'A334', 'A876', 'A435', 'A427', 'A314', 'A364', 'A871', 'A302', 'A325', 'A370', 'A847', 'A360', 'A454', 'A410', 'A869', 'A347'])

# %% [markdown]
# ### Renomeando as colunas

# %%
df = renameDatasetColumns(load(dict_data["A316"][1]))

# %% [markdown]
# ### Showing info data

# %%
print(dict_data["A316"][0])
# Out:
# Nome: CAICO
# Codigo Estacao: A316
# Latitude: -6.46749999
# Longitude: -37.08499999
# Altitude: 171.26
# Situacao: Operante
# Data Inicial: 2007-01-06
# Data Final: 2023-09-10
# Periodicidade da Medicao: Horaria

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146208 entries, 0 to 146207
# Data columns (total 22 columns):
#  #   Column                                              Non-Null Count   Dtype
# ---  ------                                              --------------   -----
#  0   data_medicao                                        146208 non-null  object
#  1   hora_medicao                                        146208 non-null  int64
#  2   precipitacao_total_horario_mm                       114106 non-null  float64
#  3   pressao_atmosferica_ao_nivel_da_estacao_horaria_mb  120369 non-null  float64
#  4   pressao_atmosferica_reduzida_nivel_do_mar_aut_mb    120358 non-null  float64
#  5   pressao_atmosferica_max_na_hora_ant_aut_mb          120191 non-null  float64
#  6   pressao_atmosferica_min_na_hora_ant_aut_mb          120191 non-null  float64
#  7   radiacao_global_kjm2                                120257 non-null  float64
#  8   temperatura_da_cpu_da_estacao_c                     119607 non-null  float64
#  9   temperatura_do_ar_bulbo_seco_horaria_c              120368 non-null  float64
#  10  temperatura_do_ponto_de_orvalho_c                   120368 non-null  float64
#  11  temperatura_maxima_na_hora_ant_aut_c                120189 non-null  float64
#  12  temperatura_minima_na_hora_ant_aut_c                120189 non-null  float64
#  13  temperatura_orvalho_max_na_hora_ant_aut_c           120189 non-null  float64
#  14  temperatura_orvalho_min_na_hora_ant_aut_c           120189 non-null  float64
#  15  tensao_da_bateria_da_estacao_v                      119607 non-null  float64
#  16  umidade_rel_max_na_hora_ant_aut_perc                120189 non-null  float64
#  17  umidade_rel_min_na_hora_ant_aut_perc                120189 non-null  float64
#  18  umidade_relativa_do_ar_horaria_perc                 120368 non-null  float64
#  19  vento_direcao_horaria_gr__gr                        120362 non-null  float64
#  20  vento_rajada_maxima_ms                              119990 non-null  float64
#  21  vento_velocidade_horaria_ms                         120363 non-null  float64
# dtypes: float64(20), int64(1), object(1)
# memory usage: 24.5+ MB

# %% [markdown]
# O dataset contém uma quantidade consderável de nulos. Neste caso, vamos remover os nulos com base na característica teórica mais importante, a radiação. Mas antes, vamos só ver a porcentagem de nulos por coluna.

# %%
get_perc_nulls(df)
# Out:
# data_medicao                                           0.000000
# hora_medicao                                           0.000000
# precipitacao_total_horario_mm                         21.956391
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb    17.672768
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb      17.680291
# pressao_atmosferica_max_na_hora_ant_aut_mb            17.794512
# pressao_atmosferica_min_na_hora_ant_aut_mb            17.794512
# radiacao_global_kjm2                                  17.749371
# temperatura_da_cpu_da_estacao_c                       18.193943
# temperatura_do_ar_bulbo_seco_horaria_c                17.673452
# temperatura_do_ponto_de_orvalho_c                     17.673452
# temperatura_maxima_na_hora_ant_aut_c                  17.795880
# temperatura_minima_na_hora_ant_aut_c                  17.795880
# temperatura_orvalho_max_na_hora_ant_aut_c             17.795880
# temperatura_orvalho_min_na_hora_ant_aut_c             17.795880
# tensao_da_bateria_da_estacao_v                        18.193943
# umidade_rel_max_na_hora_ant_aut_perc                  17.795880
# umidade_rel_min_na_hora_ant_aut_perc                  17.795880
# umidade_relativa_do_ar_horaria_perc                   17.673452
# vento_direcao_horaria_gr__gr                          17.677555
# vento_rajada_maxima_ms                                17.931987
# vento_velocidade_horaria_ms                           17.676871
# dtype: float64

# %%
df_non_null = removeNulls(df, "radiacao_global_kjm2")

# %% [markdown]
# ### Configurando campos de data e hora.
# Como a coluna `data_medicao` e `hora_medicao` estão separadas e não são do tipo date/time, precisamos criar uma coluna que seja desse tipo.

# %%
df_non_null_dt = create_datetime_feature(df_non_null)
df_non_null_dt = create_split_date_features(df_non_null_dt)

# %% [markdown]
# ### Plot inicial dos dados

# %%
df_non_null_dt.head().T
# Out:
#                                                                      21  \
# precipitacao_total_horario_mm                                       0.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb                988.6
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb             1007.88472
# pressao_atmosferica_max_na_hora_ant_aut_mb                        988.7
# pressao_atmosferica_min_na_hora_ant_aut_mb                        987.8
# radiacao_global_kjm2                                            122.094
# temperatura_da_cpu_da_estacao_c                                     NaN
# temperatura_do_ar_bulbo_seco_horaria_c                             32.5
# temperatura_do_ponto_de_orvalho_c                                  19.0
# temperatura_maxima_na_hora_ant_aut_c                               36.0
# temperatura_minima_na_hora_ant_aut_c                               32.5
# temperatura_orvalho_max_na_hora_ant_aut_c                          19.0
# temperatura_orvalho_min_na_hora_ant_aut_c                          14.3
# tensao_da_bateria_da_estacao_v                                      NaN
# umidade_rel_max_na_hora_ant_aut_perc                               45.0
# umidade_rel_min_na_hora_ant_aut_perc                               28.0
# umidade_relativa_do_ar_horaria_perc                                45.0
# vento_direcao_horaria_gr__gr                                       65.0
# vento_rajada_maxima_ms                                              NaN
# vento_velocidade_horaria_ms                                         6.1
# data_hora                                           2007-01-06 21:00:00
# hora                                                                 21
# dia                                                                   6
# mes                                                                   1
# ano                                                                2007
#
#                                                                      22  \
# precipitacao_total_horario_mm                                       0.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb                989.6
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb            1009.006801
# pressao_atmosferica_max_na_hora_ant_aut_mb                        989.6
# pressao_atmosferica_min_na_hora_ant_aut_mb                        988.6
# radiacao_global_kjm2                                              -3.53
# temperatura_da_cpu_da_estacao_c                                     NaN
# temperatura_do_ar_bulbo_seco_horaria_c                             30.9
# temperatura_do_ponto_de_orvalho_c                                  19.8
# temperatura_maxima_na_hora_ant_aut_c                               32.5
# temperatura_minima_na_hora_ant_aut_c                               30.9
# temperatura_orvalho_max_na_hora_ant_aut_c                          19.8
# temperatura_orvalho_min_na_hora_ant_aut_c                          19.0
# tensao_da_bateria_da_estacao_v                                      NaN
# umidade_rel_max_na_hora_ant_aut_perc                               52.0
# umidade_rel_min_na_hora_ant_aut_perc                               45.0
# umidade_relativa_do_ar_horaria_perc                                52.0
# vento_direcao_horaria_gr__gr                                       88.0
# vento_rajada_maxima_ms                                             11.0
# vento_velocidade_horaria_ms                                         5.5
# data_hora                                           2007-01-06 22:00:00
# hora                                                                 22
# dia                                                                   6
# mes                                                                   1
# ano                                                                2007
#
#                                                                      23  \
# precipitacao_total_horario_mm                                       0.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb                990.9
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb            1010.423065
# pressao_atmosferica_max_na_hora_ant_aut_mb                        990.9
# pressao_atmosferica_min_na_hora_ant_aut_mb                        989.6
# radiacao_global_kjm2                                              -3.54
# temperatura_da_cpu_da_estacao_c                                     NaN
# temperatura_do_ar_bulbo_seco_horaria_c                             29.5
# temperatura_do_ponto_de_orvalho_c                                  19.1
# temperatura_maxima_na_hora_ant_aut_c                               30.9
# temperatura_minima_na_hora_ant_aut_c                               29.5
# temperatura_orvalho_max_na_hora_ant_aut_c                          19.9
# temperatura_orvalho_min_na_hora_ant_aut_c                          19.1
# tensao_da_bateria_da_estacao_v                                      NaN
# umidade_rel_max_na_hora_ant_aut_perc                               54.0
# umidade_rel_min_na_hora_ant_aut_perc                               52.0
# umidade_relativa_do_ar_horaria_perc                                54.0
# vento_direcao_horaria_gr__gr                                       84.0
# vento_rajada_maxima_ms                                             12.3
# vento_velocidade_horaria_ms                                         5.7
# data_hora                                           2007-01-06 23:00:00
# hora                                                                 23
# dia                                                                   6
# mes                                                                   1
# ano                                                                2007
#
#                                                                      24  \
# precipitacao_total_horario_mm                                       0.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb                991.5
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb            1011.113414
# pressao_atmosferica_max_na_hora_ant_aut_mb                        991.6
# pressao_atmosferica_min_na_hora_ant_aut_mb                        990.9
# radiacao_global_kjm2                                             -3.503
# temperatura_da_cpu_da_estacao_c                                     NaN
# temperatura_do_ar_bulbo_seco_horaria_c                             28.3
# temperatura_do_ponto_de_orvalho_c                                  19.7
# temperatura_maxima_na_hora_ant_aut_c                               29.4
# temperatura_minima_na_hora_ant_aut_c                               28.3
# temperatura_orvalho_max_na_hora_ant_aut_c                          19.7
# temperatura_orvalho_min_na_hora_ant_aut_c                          19.1
# tensao_da_bateria_da_estacao_v                                      NaN
# umidade_rel_max_na_hora_ant_aut_perc                               60.0
# umidade_rel_min_na_hora_ant_aut_perc                               54.0
# umidade_relativa_do_ar_horaria_perc                                60.0
# vento_direcao_horaria_gr__gr                                       88.0
# vento_rajada_maxima_ms                                             11.3
# vento_velocidade_horaria_ms                                         5.4
# data_hora                                           2007-01-07 00:00:00
# hora                                                                  0
# dia                                                                   7
# mes                                                                   1
# ano                                                                2007
#
#                                                                      25
# precipitacao_total_horario_mm                                       0.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb                991.8
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb            1011.478678
# pressao_atmosferica_max_na_hora_ant_aut_mb                        991.8
# pressao_atmosferica_min_na_hora_ant_aut_mb                        991.5
# radiacao_global_kjm2                                             -3.509
# temperatura_da_cpu_da_estacao_c                                     NaN
# temperatura_do_ar_bulbo_seco_horaria_c                             27.4
# temperatura_do_ponto_de_orvalho_c                                  19.6
# temperatura_maxima_na_hora_ant_aut_c                               28.3
# temperatura_minima_na_hora_ant_aut_c                               27.4
# temperatura_orvalho_max_na_hora_ant_aut_c                          20.1
# temperatura_orvalho_min_na_hora_ant_aut_c                          19.6
# tensao_da_bateria_da_estacao_v                                      NaN
# umidade_rel_max_na_hora_ant_aut_perc                               63.0
# umidade_rel_min_na_hora_ant_aut_perc                               60.0
# umidade_relativa_do_ar_horaria_perc                                63.0
# vento_direcao_horaria_gr__gr                                       81.0
# vento_rajada_maxima_ms                                             12.5
# vento_velocidade_horaria_ms                                         5.2
# data_hora                                           2007-01-07 01:00:00
# hora                                                                  1
# dia                                                                   7
# mes                                                                   1
# ano                                                                2007

# %%
df = df_non_null_dt

# %% [markdown]
# ### Algumas estatísticas e Outliers
# Uma checagem rápida das estatísticas dos dados para detectar em um rimeiro momento a presença de outliers.

# %%
df.describe().T
# Out:
#                                                        count  \
# precipitacao_total_horario_mm                       113994.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb  120257.0
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb    120247.0
# pressao_atmosferica_max_na_hora_ant_aut_mb          120079.0
# pressao_atmosferica_min_na_hora_ant_aut_mb          120079.0
# radiacao_global_kjm2                                120257.0
# temperatura_da_cpu_da_estacao_c                     119497.0
# temperatura_do_ar_bulbo_seco_horaria_c              120257.0
# temperatura_do_ponto_de_orvalho_c                   120257.0
# temperatura_maxima_na_hora_ant_aut_c                120079.0
# temperatura_minima_na_hora_ant_aut_c                120079.0
# temperatura_orvalho_max_na_hora_ant_aut_c           120079.0
# temperatura_orvalho_min_na_hora_ant_aut_c           120079.0
# tensao_da_bateria_da_estacao_v                      119497.0
# umidade_rel_max_na_hora_ant_aut_perc                120079.0
# umidade_rel_min_na_hora_ant_aut_perc                120079.0
# umidade_relativa_do_ar_horaria_perc                 120257.0
# vento_direcao_horaria_gr__gr                        120252.0
# vento_rajada_maxima_ms                              119880.0
# vento_velocidade_horaria_ms                         120253.0
# data_hora                                             120257
# hora                                                120257.0
# dia                                                 120257.0
# mes                                                 120257.0
# ano                                                 120257.0
#
#                                                                              mean  \
# precipitacao_total_horario_mm                                            0.058545
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb                     992.947482
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb                       1012.57832
# pressao_atmosferica_max_na_hora_ant_aut_mb                             993.254154
# pressao_atmosferica_min_na_hora_ant_aut_mb                             992.668084
# radiacao_global_kjm2                                                  1027.399741
# temperatura_da_cpu_da_estacao_c                                         30.482255
# temperatura_do_ar_bulbo_seco_horaria_c                                  28.527212
# temperatura_do_ponto_de_orvalho_c                                       17.626213
# temperatura_maxima_na_hora_ant_aut_c                                    29.193496
# temperatura_minima_na_hora_ant_aut_c                                    27.842748
# temperatura_orvalho_max_na_hora_ant_aut_c                               18.148222
# temperatura_orvalho_min_na_hora_ant_aut_c                               17.137848
# tensao_da_bateria_da_estacao_v                                           12.73257
# umidade_rel_max_na_hora_ant_aut_perc                                    58.405791
# umidade_rel_min_na_hora_ant_aut_perc                                    52.988583
# umidade_relativa_do_ar_horaria_perc                                     55.573214
# vento_direcao_horaria_gr__gr                                           115.167789
# vento_rajada_maxima_ms                                                   6.913594
# vento_velocidade_horaria_ms                                              3.003065
# data_hora                                           2014-04-13 20:14:09.490673920
# hora                                                                       11.817
# dia                                                                     15.702911
# mes                                                                      6.532934
# ano                                                                   2013.781202
#
#                                                                     min  \
# precipitacao_total_horario_mm                                       0.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb                983.6
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb            1002.673769
# pressao_atmosferica_max_na_hora_ant_aut_mb                        984.0
# pressao_atmosferica_min_na_hora_ant_aut_mb                        983.5
# radiacao_global_kjm2                                              -7.02
# temperatura_da_cpu_da_estacao_c                                    19.0
# temperatura_do_ar_bulbo_seco_horaria_c                             18.3
# temperatura_do_ponto_de_orvalho_c                                   2.2
# temperatura_maxima_na_hora_ant_aut_c                               18.9
# temperatura_minima_na_hora_ant_aut_c                               18.1
# temperatura_orvalho_max_na_hora_ant_aut_c                           3.6
# temperatura_orvalho_min_na_hora_ant_aut_c                           1.4
# tensao_da_bateria_da_estacao_v                                      9.9
# umidade_rel_max_na_hora_ant_aut_perc                               14.0
# umidade_rel_min_na_hora_ant_aut_perc                               12.0
# umidade_relativa_do_ar_horaria_perc                                12.0
# vento_direcao_horaria_gr__gr                                        1.0
# vento_rajada_maxima_ms                                              0.6
# vento_velocidade_horaria_ms                                         0.1
# data_hora                                           2007-01-06 21:00:00
# hora                                                                0.0
# dia                                                                 1.0
# mes                                                                 1.0
# ano                                                              2007.0
#
#                                                                     25%  \
# precipitacao_total_horario_mm                                       0.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb                991.3
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb            1010.856286
# pressao_atmosferica_max_na_hora_ant_aut_mb                        991.6
# pressao_atmosferica_min_na_hora_ant_aut_mb                        991.0
# radiacao_global_kjm2                                              -3.54
# temperatura_da_cpu_da_estacao_c                                    27.0
# temperatura_do_ar_bulbo_seco_horaria_c                             25.1
# temperatura_do_ponto_de_orvalho_c                                  15.7
# temperatura_maxima_na_hora_ant_aut_c                               25.5
# temperatura_minima_na_hora_ant_aut_c                               24.7
# temperatura_orvalho_max_na_hora_ant_aut_c                          16.3
# temperatura_orvalho_min_na_hora_ant_aut_c                          15.0
# tensao_da_bateria_da_estacao_v                                     12.3
# umidade_rel_max_na_hora_ant_aut_perc                               43.0
# umidade_rel_min_na_hora_ant_aut_perc                               36.0
# umidade_relativa_do_ar_horaria_perc                                39.0
# vento_direcao_horaria_gr__gr                                       89.0
# vento_rajada_maxima_ms                                              5.0
# vento_velocidade_horaria_ms                                         2.0
# data_hora                                           2010-06-15 20:00:00
# hora                                                                6.0
# dia                                                                 8.0
# mes                                                                 4.0
# ano                                                              2010.0
#
#                                                                     50%  \
# precipitacao_total_horario_mm                                       0.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb                993.0
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb            1012.632226
# pressao_atmosferica_max_na_hora_ant_aut_mb                        993.3
# pressao_atmosferica_min_na_hora_ant_aut_mb                        992.7
# radiacao_global_kjm2                                            191.948
# temperatura_da_cpu_da_estacao_c                                    30.0
# temperatura_do_ar_bulbo_seco_horaria_c                             27.9
# temperatura_do_ponto_de_orvalho_c                                  17.9
# temperatura_maxima_na_hora_ant_aut_c                               28.7
# temperatura_minima_na_hora_ant_aut_c                               27.2
# temperatura_orvalho_max_na_hora_ant_aut_c                          18.3
# temperatura_orvalho_min_na_hora_ant_aut_c                          17.5
# tensao_da_bateria_da_estacao_v                                     12.5
# umidade_rel_max_na_hora_ant_aut_perc                               60.0
# umidade_rel_min_na_hora_ant_aut_perc                               54.0
# umidade_relativa_do_ar_horaria_perc                                57.0
# vento_direcao_horaria_gr__gr                                      106.0
# vento_rajada_maxima_ms                                              7.0
# vento_velocidade_horaria_ms                                         2.9
# data_hora                                           2013-12-07 22:00:00
# hora                                                               12.0
# dia                                                                16.0
# mes                                                                 7.0
# ano                                                              2013.0
#
#                                                                     75%  \
# precipitacao_total_horario_mm                                       0.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb                994.7
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb             1014.43419
# pressao_atmosferica_max_na_hora_ant_aut_mb                        994.9
# pressao_atmosferica_min_na_hora_ant_aut_mb                        994.4
# radiacao_global_kjm2                                           2114.761
# temperatura_da_cpu_da_estacao_c                                    34.0
# temperatura_do_ar_bulbo_seco_horaria_c                             31.8
# temperatura_do_ponto_de_orvalho_c                                  19.9
# temperatura_maxima_na_hora_ant_aut_c                               32.7
# temperatura_minima_na_hora_ant_aut_c                               30.9
# temperatura_orvalho_max_na_hora_ant_aut_c                          20.4
# temperatura_orvalho_min_na_hora_ant_aut_c                          19.5
# tensao_da_bateria_da_estacao_v                                     13.0
# umidade_rel_max_na_hora_ant_aut_perc                               72.0
# umidade_rel_min_na_hora_ant_aut_perc                               67.0
# umidade_relativa_do_ar_horaria_perc                                69.0
# vento_direcao_horaria_gr__gr                                      124.0
# vento_rajada_maxima_ms                                              8.8
# vento_velocidade_horaria_ms                                         3.9
# data_hora                                           2017-12-17 13:00:00
# hora                                                               18.0
# dia                                                                23.0
# mes                                                                 9.0
# ano                                                              2017.0
#
#                                                                     max  \
# precipitacao_total_horario_mm                                      55.8
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb               1001.2
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb            1021.063821
# pressao_atmosferica_max_na_hora_ant_aut_mb                       1001.2
# pressao_atmosferica_min_na_hora_ant_aut_mb                       1001.0
# radiacao_global_kjm2                                           4246.893
# temperatura_da_cpu_da_estacao_c                                    44.0
# temperatura_do_ar_bulbo_seco_horaria_c                             39.5
# temperatura_do_ponto_de_orvalho_c                                  26.3
# temperatura_maxima_na_hora_ant_aut_c                               40.1
# temperatura_minima_na_hora_ant_aut_c                               38.7
# temperatura_orvalho_max_na_hora_ant_aut_c                          26.5
# temperatura_orvalho_min_na_hora_ant_aut_c                          24.5
# tensao_da_bateria_da_estacao_v                                     14.3
# umidade_rel_max_na_hora_ant_aut_perc                               97.0
# umidade_rel_min_na_hora_ant_aut_perc                               97.0
# umidade_relativa_do_ar_horaria_perc                                97.0
# vento_direcao_horaria_gr__gr                                      360.0
# vento_rajada_maxima_ms                                             24.8
# vento_velocidade_horaria_ms                                         9.4
# data_hora                                           2023-09-10 23:00:00
# hora                                                               23.0
# dia                                                                31.0
# mes                                                                12.0
# ano                                                              2023.0
#
#                                                             std
# precipitacao_total_horario_mm                          0.859526
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb     2.477146
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb       2.670703
# pressao_atmosferica_max_na_hora_ant_aut_mb             2.432824
# pressao_atmosferica_min_na_hora_ant_aut_mb             2.488053
# radiacao_global_kjm2                                1247.990849
# temperatura_da_cpu_da_estacao_c                        4.688791
# temperatura_do_ar_bulbo_seco_horaria_c                 4.070311
# temperatura_do_ponto_de_orvalho_c                      3.214692
# temperatura_maxima_na_hora_ant_aut_c                   4.252992
# temperatura_minima_na_hora_ant_aut_c                   3.863635
# temperatura_orvalho_max_na_hora_ant_aut_c              3.121696
# temperatura_orvalho_min_na_hora_ant_aut_c              3.308523
# tensao_da_bateria_da_estacao_v                          0.59252
# umidade_rel_max_na_hora_ant_aut_perc                  19.247905
# umidade_rel_min_na_hora_ant_aut_perc                  19.458634
# umidade_relativa_do_ar_horaria_perc                   19.457407
# vento_direcao_horaria_gr__gr                          59.276659
# vento_rajada_maxima_ms                                  2.64091
# vento_velocidade_horaria_ms                            1.353933
# data_hora                                                   NaN
# hora                                                   6.760305
# dia                                                    8.810988
# mes                                                    3.421533
# ano                                                    4.444104

# %% [markdown]
# #### Radiação
# O desvio padrão da radiação está muito alto em relação a média. Vamos fazer algumas análises e tentar chegar numa conclusão.

# %% [markdown]
# ##### Percentil

# %%
for i in range(0, 101):
    value_str = str(i)

    if len(value_str) == 1:
        value_str = "0.0"+value_str
    
    elif len(value_str) == 2:
        value_str = "0."+value_str
    else:
        value_str = "1.0"
    
    double_value = float(value_str) 
    print(value_str, df["radiacao_global_kjm2"].quantile(double_value))
# Out:
# 0.00 -7.02
# 0.01 -3.54
# 0.02 -3.54
# 0.03 -3.54
# 0.04 -3.54
# 0.05 -3.54
# 0.06 -3.54
# 0.07 -3.54
# 0.08 -3.54
# 0.09 -3.54
# 0.10 -3.54
# 0.11 -3.54
# 0.12 -3.54
# 0.13 -3.54
# 0.14 -3.54
# 0.15 -3.54
# 0.16 -3.54
# 0.17 -3.54
# 0.18 -3.54
# 0.19 -3.54
# 0.20 -3.54
# 0.21 -3.54
# 0.22 -3.54
# 0.23 -3.54
# 0.24 -3.54
# 0.25 -3.54
# 0.26 -3.54
# 0.27 -3.54
# 0.28 -3.54
# 0.29 -3.54
# 0.30 -3.54
# 0.31 -3.54
# 0.32 -3.538
# 0.33 -3.528
# 0.34 -3.505
# 0.35 -3.463
# 0.36 -3.386
# 0.37 -3.276
# 0.38 -3.116
# 0.39 -2.854
# 0.40 -2.459
# 0.41 -1.6920800000000018
# 0.42 0.6215999999999839
# 0.43 7.997160000000047
# 0.44 15.604319999999992
# 0.45 24.99700000000002
# 0.46 35.076120000000024
# 0.47 52.782959999999996
# 0.48 84.3051999999999
# 0.49 129.6829600000001
# 0.50 191.948
# 0.51 278.61243999999976
# 0.52 376.5618800000001
# 0.53 458.35204000000004
# 0.54 523.4443600000001
# 0.55 584.2674000000001
# 0.56 640.22856
# 0.57 709.7487199999999
# 0.58 798.9383599999999
# 0.59 885.0553199999999
# 0.60 979.6691999999997
# 0.61 1070.6788800000015
# 0.62 1170.1194400000002
# 0.63 1259.7580799999998
# 0.64 1333.9336399999997
# 0.65 1402.2186000000015
# 0.66 1468.8430800000008
# 0.67 1533.88928
# 0.68 1591.6540400000001
# 0.69 1668.6088399999999
# 0.70 1746.283
# 0.71 1819.74904
# 0.72 1895.4801999999988
# 0.73 1972.97748
# 0.74 2044.85136
# 0.75 2114.761
# 0.76 2183.6114799999996
# 0.77 2256.3844
# 0.78 2321.5466
# 0.79 2383.3688
# 0.80 2442.3451999999997
# 0.81 2509.88016
# 0.82 2577.37252
# 0.83 2644.0476
# 0.84 2705.39356
# 0.85 2768.0534
# 0.86 2827.94784
# 0.87 2892.69888
# 0.88 2957.55728
# 0.89 3017.381
# 0.90 3071.2966000000006
# 0.91 3125.0986000000003
# 0.92 3181.4789200000005
# 0.93 3242.6432800000002
# 0.94 3306.64392
# 0.95 3379.1576
# 0.96 3452.345
# 0.97 3532.3003599999997
# 0.98 3610.24724
# 0.99 3697.85876
# 1.0 4246.893

# %% [markdown]
# Como vimos, mudanças significtiva nos dados ocorrem a partir do 42th percentil. Vamos agora ordenar para ver se o maior valor está muito diferentes dos próximos.

# %%
df.sort_values(by="radiacao_global_kjm2", ascending=False)["radiacao_global_kjm2"].head(10)
# Out:
# 59943     4246.893
# 96927     4158.044
# 10767     4136.190
# 62847     4103.250
# 140680    4102.599
# 130599    4091.730
# 114928    4081.834
# 50655     4076.577
# 53703     4069.840
# 62775     4061.207
# Name: radiacao_global_kjm2, dtype: float64

# %%
df.sort_values(by="radiacao_global_kjm2", ascending=True)["radiacao_global_kjm2"].head(10)
# Out:
# 16130   -7.02
# 5740    -3.72
# 15988   -3.72
# 60670   -3.54
# 56257   -3.54
# 56258   -3.54
# 56259   -3.54
# 56260   -3.54
# 56261   -3.54
# 56262   -3.54
# Name: radiacao_global_kjm2, dtype: float64

# %% [markdown]
# Aparentemente, não há outliers, vamos calcular o z-score para essa coluna: `Z = (X−µ) ÷ σ`

# %%
df[["radiacao_global_kjm2"]].apply(zscore).sort_values(by="radiacao_global_kjm2", ascending=False)
# Out:
#         radiacao_global_kjm2
# 59943               2.579752
# 96927               2.508558
# 10767               2.491046
# 62847               2.464652
# 140680              2.464130
# ...                      ...
# 60431              -0.826083
# 146207             -0.826083
# 5740               -0.826227
# 15988              -0.826227
# 16130              -0.828871
#
# [120257 rows x 1 columns]

# %% [markdown]
# O z-score não mostrou nada muito atipico. Vamos plotar o histograma.

# %%
df["radiacao_global_kjm2"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[df["radiacao_global_kjm2"]>0]["radiacao_global_kjm2"].count()
# Out:
# 69941

# %%
df[df["radiacao_global_kjm2"]>0]["radiacao_global_kjm2"].describe()
# Out:
# count    69941.000000
# mean      1768.966749
# std       1167.736345
# min          0.002000
# 25%        664.156000
# 50%       1814.294000
# 75%       2797.097000
# max       4246.893000
# Name: radiacao_global_kjm2, dtype: float64

# %%
df[df["radiacao_global_kjm2"]>0]["radiacao_global_kjm2"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Apesar do desbalanceamento dos dados, não se pode afirmar que a radiação tenha outliers. Portanto, não removeremos nenhum registro. Entretanto, podemos remover posteriormente apenas para ver o comportamento dos dados.

# %%
# df = df[df["radiacao_global_kjm2"]>0]

# %% [markdown]
# #### Vento
# Aparentemente, a variável do vento contém alguns dados desbalanceados, como podemos ver aqui no histograma

# %%
sns.set_theme(rc={'figure.figsize':(8.7,5.27)})
df["vento_rajada_maxima_ms"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[df["vento_rajada_maxima_ms"] > 15]["vento_rajada_maxima_ms"].count()
# Out:
# 135

# %%
df = df[df["vento_rajada_maxima_ms"] <=15]

# %% [markdown]
# ### Removendo colunas
# A coluna `precipitacao_total_horario_mm` tem muitos zeros ou nulos, portanto, iremos remove-la.

# %%
df["precipitacao_total_horario_mm"].value_counts()
# Out:
# precipitacao_total_horario_mm
# 0.0     110524
# 0.2       1263
# 0.4        324
# 0.6        186
# 0.8        128
#          ...
# 23.6         1
# 16.0         1
# 30.0         1
# 20.8         1
# 16.6         1
# Name: count, Length: 126, dtype: int64

# %%
df["precipitacao_total_horario_mm"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
without_relevance = ["temperatura_do_ponto_de_orvalho_c",
                 "temperatura_orvalho_max_na_hora_ant_aut_c",
                 "temperatura_orvalho_min_na_hora_ant_aut_c",
                 "tensao_da_bateria_da_estacao_v",
                 "vento_direcao_horaria_gr__gr",
                 "vento_velocidade_horaria_ms"]

many_nulls_zeros = ["precipitacao_total_horario_mm"]

without_relevance.extend(many_nulls_zeros)

df = df.drop(without_relevance, axis=1)

# %% [markdown]
# ### Feature engineering
# Algumas colunas possuem comportamento similar. Portanto, podemos mescla-las em uma só.

# %% [markdown]
# #### Atmo Press

# %%
join_press = [
            "pressao_atmosferica_ao_nivel_da_estacao_horaria_mb", 
            "pressao_atmosferica_reduzida_nivel_do_mar_aut_mb",
            "pressao_atmosferica_max_na_hora_ant_aut_mb",
            "pressao_atmosferica_min_na_hora_ant_aut_mb"
       ]
df[join_press].describe().T
# Out:
#                                                        count         mean  \
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb  119745.0   992.942794
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb    119735.0  1012.572758
# pressao_atmosferica_max_na_hora_ant_aut_mb          119745.0   993.252782
# pressao_atmosferica_min_na_hora_ant_aut_mb          119745.0   992.666993
#
#                                                          std          min  \
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb  2.476428   983.600000
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb    2.669704  1002.673769
# pressao_atmosferica_max_na_hora_ant_aut_mb          2.432882   984.000000
# pressao_atmosferica_min_na_hora_ant_aut_mb          2.487493   983.500000
#
#                                                             25%          50%  \
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb   991.300000   993.000000
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb    1010.851063  1012.627017
# pressao_atmosferica_max_na_hora_ant_aut_mb           991.600000   993.300000
# pressao_atmosferica_min_na_hora_ant_aut_mb           991.000000   992.700000
#
#                                                             75%          max
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb   994.700000  1001.200000
# pressao_atmosferica_reduzida_nivel_do_mar_aut_mb    1014.426097  1021.063821
# pressao_atmosferica_max_na_hora_ant_aut_mb           994.900000  1001.200000
# pressao_atmosferica_min_na_hora_ant_aut_mb           994.400000  1001.000000

# %%
df_local =  df[join_press]
df["press_atmo"] = df_local.mean(axis=1)
df = df.drop(join_press, axis=1)

# %% [markdown]
# #### Temperature

# %%
mean_temp = [
        "temperatura_do_ar_bulbo_seco_horaria_c",
        "temperatura_da_cpu_da_estacao_c", 
        "temperatura_maxima_na_hora_ant_aut_c",
        "temperatura_minima_na_hora_ant_aut_c"]

df[mean_temp].describe().T
# Out:
#                                            count       mean       std   min  \
# temperatura_do_ar_bulbo_seco_horaria_c  119745.0  28.539008  4.068489  18.3
# temperatura_da_cpu_da_estacao_c         118986.0  30.497201  4.683519  19.0
# temperatura_maxima_na_hora_ant_aut_c    119745.0  29.198433  4.251548  18.9
# temperatura_minima_na_hora_ant_aut_c    119745.0  27.850314  3.861403  18.1
#
#                                          25%   50%   75%   max
# temperatura_do_ar_bulbo_seco_horaria_c  25.1  28.0  31.8  39.5
# temperatura_da_cpu_da_estacao_c         27.0  30.0  34.0  44.0
# temperatura_maxima_na_hora_ant_aut_c    25.5  28.7  32.7  40.1
# temperatura_minima_na_hora_ant_aut_c    24.7  27.2  30.9  38.7

# %%
df_local =  df[mean_temp]
df["temperature"] = df_local.mean(axis=1)
df = df.drop(mean_temp, axis=1)

# %% [markdown]
# #### Humidity

# %%
mean_humidity = ["umidade_rel_max_na_hora_ant_aut_perc",
            "umidade_rel_min_na_hora_ant_aut_perc",
            "umidade_relativa_do_ar_horaria_perc"]

df[mean_humidity].describe().T
# Out:
#                                          count       mean        std   min  \
# umidade_rel_max_na_hora_ant_aut_perc  119745.0  58.373026  19.240328  14.0
# umidade_rel_min_na_hora_ant_aut_perc  119745.0  52.967113  19.455736  12.0
# umidade_relativa_do_ar_horaria_perc   119745.0  55.522393  19.452273  12.0
#
#                                        25%   50%   75%   max
# umidade_rel_max_na_hora_ant_aut_perc  43.0  60.0  72.0  97.0
# umidade_rel_min_na_hora_ant_aut_perc  36.0  54.0  67.0  97.0
# umidade_relativa_do_ar_horaria_perc   39.0  57.0  69.0  97.0

# %%
df_local =  df[mean_humidity]
df["humidity"] = df_local.mean(axis=1)
df = df.drop(mean_humidity, axis=1)

# %%
df.head()
# Out:
#     radiacao_global_kjm2  vento_rajada_maxima_ms           data_hora  hora  \
# 22                -3.530                    11.0 2007-01-06 22:00:00    22
# 23                -3.540                    12.3 2007-01-06 23:00:00    23
# 24                -3.503                    11.3 2007-01-07 00:00:00     0
# 25                -3.509                    12.5 2007-01-07 01:00:00     1
# 26                -3.532                    10.5 2007-01-07 02:00:00     2
#
#     dia  mes   ano  press_atmo  temperature   humidity
# 22    6    1  2007  994.201700    31.433333  49.666667
# 23    6    1  2007  995.455766    29.966667  53.333333
# 24    7    1  2007  996.278353    28.666667  58.000000
# 25    7    1  2007  996.644669    27.700000  62.000000
# 26    7    1  2007  996.951123    27.200000  63.333333

# %% [markdown]
# ### Analise com datas
# Aqui iremos plotar a radiação por data

# %% [markdown]
# #### Ano

# %%
df_year = df[["ano", "radiacao_global_kjm2"]].groupby(['ano']).mean().reset_index()

# %% [markdown]
# #### Média e desvio
# Apenas para garantir que não temos uma discrepância entre média e desvio, vamos exibir por ano.

# %%
df[["ano", "radiacao_global_kjm2"]].groupby(['ano'])\
['radiacao_global_kjm2'].agg(['mean','std'])
# Out:
#              mean          std
# ano
# 2007   929.518862  1223.676371
# 2008   919.556370  1221.063691
# 2009   910.514182  1210.482467
# 2010   957.406979  1236.516543
# 2011   903.751096  1204.251160
# 2012   962.945153  1251.542288
# 2013   924.225079  1220.147932
# 2014   975.635201  1223.531850
# 2015   917.344371  1208.785753
# 2016   943.115869  1234.111096
# 2017   953.640666  1230.152724
# 2018   953.927064  1242.066600
# 2019   915.254620  1210.733718
# 2020  1217.788960  1280.812514
# 2021  2169.004600   946.367039
# 2022  2224.128353   897.445542
# 2023  1874.681836  1136.306306

# %%
df_test = df[["ano", "radiacao_global_kjm2"]].groupby(['ano'])\
['radiacao_global_kjm2'].agg(['mean','std']).reset_index()

df_test[df_test["ano"] >= 2020].agg(['mean','std'])
# Out:
#               ano         mean          std
# mean  2021.500000  1871.400937  1065.232850
# std      1.290994   461.953804   176.831077

# %%
sns.lineplot(data=df_year, x=df_year["ano"], y=df_year["radiacao_global_kjm2"])
# Out:
# <Axes: xlabel='ano', ylabel='radiacao_global_kjm2'>

# %% [markdown]
# #### Mes

# %%
df_month = df[["mes", "radiacao_global_kjm2"]].groupby(['mes']).mean().reset_index()

# %%
sns.lineplot(data=df_month, x=df_month["mes"], y=df_month["radiacao_global_kjm2"])
# Out:
# <Axes: xlabel='mes', ylabel='radiacao_global_kjm2'>

# %% [markdown]
# #### Hora

# %%
df_hour = df[["hora", "radiacao_global_kjm2"]].groupby(['hora']).mean().reset_index()

# %%
sns.lineplot(data=df_hour, x=df_hour["hora"], y=df_hour["radiacao_global_kjm2"])
# Out:
# <Axes: xlabel='hora', ylabel='radiacao_global_kjm2'>

# %% [markdown]
# #### Hora com o vento como `hue`

# %%
df_hour_wind = df[[
    "hora", 
    "radiacao_global_kjm2", 
    "vento_rajada_maxima_ms"]]\
.fillna(0)

df_hour_wind["wind_catg"] = create_category("vento_rajada_maxima_ms", df_hour_wind)
# Out:
# [ 0.6  5.   7.   8.8 15. ]

# %%
sns.lineplot(data=df_hour_wind, x=df_hour_wind["hora"], y=df_hour_wind["radiacao_global_kjm2"], hue=df_hour_wind["wind_catg"])
# Out:
# <Axes: xlabel='hora', ylabel='radiacao_global_kjm2'>

# %% [markdown]
# #### Hora com a pressão atmo. como `hue`

# %%
df_hour_press = df[[
    "hora", 
    "radiacao_global_kjm2", 
    "press_atmo"]]\
.fillna(0)

df_hour_press["press_catg"] = create_category("press_atmo", df_hour_press)
# Out:
# [ 988.44344225  996.20638025  997.8825675   999.59361725 1006.11462875]

# %%
sns.lineplot(data=df_hour_press, x=df_hour_press["hora"], y=df_hour_press["radiacao_global_kjm2"], hue=df_hour_press["press_catg"])
# Out:
# <Axes: xlabel='hora', ylabel='radiacao_global_kjm2'>

# %% [markdown]
# #### Hora com a temperatura como `hue`

# %%
df_temp = df[[
    "hora", 
    "radiacao_global_kjm2", 
    "temperature"]]\
.fillna(0)

df_temp["temp_catg"] = create_category("temperature", df_temp)
# Out:
# [18.75  25.5   28.4   32.375 40.075]

# %%
sns.lineplot(data=df_temp, x=df_temp["hora"], y=df_temp["radiacao_global_kjm2"], hue=df_temp["temp_catg"])
# Out:
# <Axes: xlabel='hora', ylabel='radiacao_global_kjm2'>

# %% [markdown]
# #### Hora com a umidade como `hue`

# %%
df_temp = df[[
    "hora", 
    "radiacao_global_kjm2", 
    "humidity"]]\
.fillna(0)

df_temp["hum_catg"] = create_category("humidity", df_temp)
# Out:
# [12.66666667 39.66666667 57.33333333 69.33333333 97.        ]

# %%
sns.lineplot(data=df_temp, x=df_temp["hora"], y=df_temp["radiacao_global_kjm2"], hue=df_temp["hum_catg"])
# Out:
# <Axes: xlabel='hora', ylabel='radiacao_global_kjm2'>

# %% [markdown]
# #### Relação linear entre radiação e vento

# %%
sns.lineplot(data=df, x=df["vento_rajada_maxima_ms"], y=df["radiacao_global_kjm2"])
# Out:
# <Axes: xlabel='vento_rajada_maxima_ms', ylabel='radiacao_global_kjm2'>

# %%
sns.lineplot(data=df, x=df["humidity"], y=df["radiacao_global_kjm2"])
# Out:
# <Axes: xlabel='humidity', ylabel='radiacao_global_kjm2'>

# %% [markdown]
# ### Conclusões
#
# #### Desbalanceamento
# O dataset possui uma quantidade razoável de nulos, quando falamos da coluna "alvo" radiação, que fica em torno de \~17%. Como não chega a ser um valor expressivo, podemos simplesmente remover os nulos dessa coluna. Em seguida, analisamos as estatisticas dos dados, como média, desvio padrão e quartis. O que foi percebido é um valor alto do desvio em relação a média, podendo indicar a presença de outliers. Entretanto, o dataset na verdade possui dados desbalanceados, tendo muitos valores negativos (~42%) na mesma faixa de valores, o que pode comppromenter uma futura previsão. Aqui podemos tratar esse desbalanceamento com algumas técnicas, como o undersampling, por exemplo. Iremos remover posteriormente, apenas para checar o comportamento dos dados quando plotamos.
#
# Ainda falando de dados desbalanceados, temos também a categoria "vento", que contém um numero pequeno de registros acima do valor 15. Portanto, para fins de previsão, podemos remove-los.
#
# Sobre a coluna de precipitação, temos valores zerados ou nulos quase em sua totalidade. Portanto, iremos remove-la do dataset.
#
# #### Feature Engineering
#
# No dataset, existem colunas que representam o mesmo conceito, e possuem medidas estatisticas (media, desvio) semelhantes. Portanto, aplicamos alguns métodos para "juntarmos" essas colunas semelhantes em uma só, como o caso das colunas de pressão atmosférica, umidade e temperatura.
#
#
# #### Analise com datas
#
# Para termos ma visão geral falando de séries temporais, agregamos os dados por ano, mes e horário, para tentar enxergar algum padrão.
#
# ##### Por ano
# Agregando os dados por ano, notou-se um comportamento incomun entre ~2008-2020, onde temos niveis baixos de radiação média ( ~935) em relação ao niveis médios a partir de 2020 ( ~1871). Não foi encontrado um motivo particular para esse comportamento.
#
# ##### Por mes
# Construindo um gráfico com dados agregados por mes, não houve nenhum ponto atípico. Os dados mostram uma maior incidência de radiação no início do ano (verão), com uma queda acentuada assim que deslocamos a coluna temporal até o meio do ano (outuno-inverno), com novo aumento da radiação assim que se aproxima do final do ano (primavera-verão).
#
# ##### Por hora
# Assim como o plot por mês, não houve nenhum comportamento atípico ao esperado, tendo a faixa ~10h-17h a maior incidência de radição do dia, caindo bruscamente a partir das 20h.
#
# ##### Valores horários por outra colunas
# Nessa análise, decidimos isolar as observações horárias por categorias (A, B, C e D) dentro de algumas colunas. Ou seja, utilizamos os quartis dessas colunas e categorizamos os valores. Ex: temperatura categoria A: de 0 a 15, categoria B: de 15 a 25, e assim por diante. As seguintes colunas foram utilzadas:
#
# - **Vento**: Percebemos uma ligeira relação diretamente proporcional entre ventos fortes e maiores niveis de radiação, porém nada relevante.
# - **Pressão atmosférica**: aqui tivemos um aumento dessa relação entre uma categoria especifica (baixa pressão atmosférica) e o nivel de radiação solar.
# - **Temperatura**: no caso da temperatura, não houve comportamento inesperado, prevalecendo as altas temperaturas com incidência da radiação.
# - **Umidade**: da mesma forma que a temperatura, também não houve nada diferente do previsto, com as baixas taxas de umidade tendo relação forte com altos valores de radiação solar.
#
# ##### Relação linear
# Como ultima análise, decidimos verificar se existe uma relação linear entre alguma coluna e os valores de radiação. Como escolha, tivemos um resultado interessante utilzando o vento novamente. O gráfico mostra que o pico de radiação é atingido quando a rajada máxima de vento fica entre 8-10 m/s, com queda acentuada ao ultrapassar esses valores. E para confirmar a relação inversamente proporcional entre umidade e a radiação, também colocamos em gráfico ambas as colunas, evidenciando esse comportamento.
