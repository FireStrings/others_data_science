# %%
# %run UtilsNew.ipynb

# %%
list_files = os.listdir("data/estacoes")[:-1]
set_plot_size(15, 20)

# %%
fig, axs = plt.subplots(nrows=len(list_files))
for i, estacao in enumerate(list_files):
    print(estacao)
    raw_anual_df = pd.read_csv("data/estacoes/" + estacao, sep=";")
    anual_df = pre_processing(raw_anual_df)
    
    
    plot_distrib_horario(anual_df, axs[i-1])
# Out:
# itacoatiara.csv
# minas_gerais_bh2.csv
# itacoatiara2.csv
# brasilia2.csv
# minas_gerais_gv.csv
# rio_de_janeiro.csv
# manaus2.csv
# curitiba2.csv
# manaus.csv
# campo_grande.csv
# pelotas.csv
# campo_grande2.csv
# brasilia.csv
# apui.csv
# cuiaba.csv
# minas_gerais_bh.csv
# mossoro.csv
# mossoro2.csv
# pelotas2.csv
# minas_gerais_gv2.csv
# mato_grosso.csv
# curitiba.csv
