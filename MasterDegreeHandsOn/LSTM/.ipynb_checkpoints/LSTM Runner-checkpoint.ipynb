# %% [markdown]
# ### Imports

# %%
# %run LSTM.ipynb

# %%
lista_estacoes = ["campo_grande", "curitiba", "manaus", "minas_gerais_gv", "mossoro", "pelotas", "brasilia", "minas_gerais_bh"]

janela_tempo = 12
results_lstm = {}
results_bilstm = {}

# %%
for estacao in lista_estacoes:
    anual_df = load_and_filter(estacao, 7, 18, False).set_index("data_hora")

    train_size = int(0.7 * (round(len(anual_df)/10)*10))

    train_df = anual_df.iloc[0:train_size]
    test_df = anual_df.iloc[train_size:]
    
    results_lstm[estacao] = {}
    results_bilstm[estacao] = {}

    # LSTM
    process_lstm(2, estacao, train_df, test_df, results_lstm, True, False, False)

    # BiLSTM
    process_lstm(5, estacao, train_df, test_df, results_bilstm, True, True, False)
# Out:
# Starting process 0 for station campo_grande with LSTM type

# %%
list_df_results = []
for estacao in lista_estacoes:
    list_df_results.append(create_table_results(estacao, "lstm", results_lstm[estacao]))
    list_df_results.append(create_table_results(estacao, "bilstm", results_bilstm[estacao]))

# %%
df_final = pd.concat(list_df_results, axis=0)

# %%
df_final.groupby(level=[0, 1]).mean().reset_index()
# Out:
#             estacao tipo_rede       mse      rmse       mae        r2
# 0          brasilia    bilstm  0.212887  0.461294  0.296436  0.801580
# 1          brasilia      lstm  0.362628  0.565199  0.430819  0.635135
# 2      campo_grande    bilstm  0.174404  0.417586  0.266606  0.819619
# 3      campo_grande      lstm  0.313177  0.538479  0.445233  0.671509
# 4          curitiba    bilstm  0.170186  0.410235  0.303938  0.788974
# 5          curitiba      lstm  0.459991  0.601415  0.520278  0.349297
# 6            manaus    bilstm  0.179537  0.420648  0.317384  0.768307
# 7            manaus      lstm  0.166737  0.407675  0.299577  0.772341
# 8   minas_gerais_bh    bilstm  0.182725  0.423072  0.302114  0.830299
# 9   minas_gerais_bh      lstm  0.284624  0.502451  0.403694  0.694751
# 10  minas_gerais_gv    bilstm  0.182781  0.427494  0.303326  0.813537
# 11  minas_gerais_gv      lstm  0.374429  0.563985  0.454808  0.655904
# 12          mossoro    bilstm  0.077810  0.274815  0.206996  0.906982
# 13          mossoro      lstm  0.112184  0.325090  0.266249  0.865361
# 14          pelotas    bilstm  0.133591  0.365368  0.246485  0.862520
# 15          pelotas      lstm  0.252914  0.479848  0.388038  0.725648

# %%
pd.set_option('display.max_rows', 100)

# %%
df_final
# Out:
#                                          mse      rmse       mae        r2
# estacao         tipo_rede execucao
# campo_grande    lstm      1         0.165657  0.407010  0.302777  0.819724
#                           2         0.495945  0.704234  0.621898  0.509757
#                           3         0.552059  0.743007  0.680393  0.430798
#                           4         0.194644  0.441185  0.332330  0.795327
#                           5         0.157577  0.396960  0.288769  0.801940
#                 bilstm    1         0.178592  0.422602  0.276304  0.816695
#                           2         0.168685  0.410712  0.268356  0.814240
#                           3         0.179955  0.424211  0.267302  0.818981
#                           4         0.173078  0.416027  0.258375  0.827421
#                           5         0.171711  0.414381  0.262694  0.820756
# curitiba        lstm      1         0.135199  0.367694  0.271804  0.807014
#                           2         1.439006  1.199586  1.144832 -1.128021
#                           3         0.384280  0.619903  0.547631  0.503297
#                           4         0.128303  0.358194  0.255604  0.840146
#                           5         0.213167  0.461700  0.381520  0.724050
#                 bilstm    1         0.146779  0.383117  0.257733  0.818561
#                           2         0.218151  0.467066  0.385815  0.731374
