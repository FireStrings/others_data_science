# %% [markdown]
# # Definitions
# - Definir estações
# - Artigo para ler: https://latamt.ieeer9.org/index.php/transactions/article/view/5563
# - Plotar hora a hora, e o describe
# - Transformação logaritmica, para variacia não constante?
# - Método Box-Cox ou deflacionar a série
# - Modelar a serie temporal
#   - Normality hypothesis tests, Anderson-Darling and Shapiro-Wilk
#   - Decompor em 3 partes: tendência, sazonalidade e resíduo
# - Aplicar estacionariedade
# - Verificar precipitação, quando tiver.
# - A press atmo do nivel da estacao ja é a media
# - Usar temp. Bulbo seco
# - Agrupar por estacoes do ano (verao, inverno, etc)
# - Corte as 5h as 21h
# - Verificar umidade no litoral
# - Pegar estacoes proximas, ir do litoral ao interior
# - Pegar principalmente duas regioes (bahia e sul, por exemplo)
# - Transfer learning entre estacoes nas regioes

# %% [markdown]
# ### Escolhendo estações
# Iremos escolher duas regiões:
# - Bahia, pegando algumas estações (umas 3) e indo do litoral até o interior.
# - RS, com o mesmo comportamento da primeira.
#
# Bahia:
# - A401
# - A413
# - A440
#
# RS:
# - A801
# - A840
# - A893
#
# Nesse Notebook, analisaremos os dados da estação A401 (Salvador, Bahia), que fica no litoral.

# %% [markdown]
# ### Imports

# %%
# %run Utils.ipynb

# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from pandas.plotting import autocorrelation_plot
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
dict_files = get_files(n=None)

# %%
# dict_files.keys()
print(dict_files["A401"][0])
# Out:
# REGIAO:;NE
# UF:;BA
# ESTACAO:;SALVADOR
# CODIGO (WMO):;A401
# LATITUDE:;-13,005515
# LONGITUDE:;-38,50576
# ALTITUDE:;47,56
# DATA DE FUNDACAO:;13/05/00

# %%
dict_files["A401"][1]
# Out:
# 'data/estacoes_solares/2023/INMET_NE_BA_A401_SALVADOR_01-01-2023_A_31-12-2023.CSV'

# %% [markdown]
# ### Pre processamento

# %%
df = load(dict_files["A401"][1])
df = renameDatasetColumns(df)
df = transform_datetime(df)
df = create_datetime_feature(df)
df = create_split_date_features(df)
df = removeNulls(df, "radiacao")
df = change_types(df)

# %%
df.head().T
# Out:
#                                                                      9   \
# precipitação_total_horário_mm                                       0.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb               1008.2
# pressão_atmosferica_max_na_hora_ant_aut_mb                       1008.2
# pressão_atmosferica_min_na_hora_ant_aut_mb                       1007.8
# radiacao                                                           47.4
# temperatura_do_ar_bulbo_seco_horaria_c                             24.0
# temperatura_do_ponto_de_orvalho_c                                  22.7
# temperatura_máxima_na_hora_ant_aut_c                               24.0
# temperatura_mínima_na_hora_ant_aut_c                               23.7
# temperatura_orvalho_max_na_hora_ant_aut_c                          22.7
# temperatura_orvalho_min_na_hora_ant_aut_c                          22.4
# umidade_rel_max_na_hora_ant_aut_perc                               93.0
# umidade_rel_min_na_hora_ant_aut_perc                               92.0
# umidade_relativa_do_ar_horaria_perc                                92.0
# vento_direção_horaria_gr__gr                                       92.0
# vento_rajada_maxima_ms                                              2.7
# vento_velocidade_horaria_ms                                         0.5
# data_hora                                           2023-01-01 09:00:00
# data                                                2023-01-01 00:00:00
# data_str                                                     2023-01-01
# hora                                                                  9
# dia                                                                   1
# mes                                                                   1
# ano                                                                2023
#
#                                                                      10  \
# precipitação_total_horário_mm                                       0.2
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb               1008.8
# pressão_atmosferica_max_na_hora_ant_aut_mb                       1008.8
# pressão_atmosferica_min_na_hora_ant_aut_mb                       1008.2
# radiacao                                                          166.5
# temperatura_do_ar_bulbo_seco_horaria_c                             25.4
# temperatura_do_ponto_de_orvalho_c                                  23.7
# temperatura_máxima_na_hora_ant_aut_c                               25.5
# temperatura_mínima_na_hora_ant_aut_c                               24.0
# temperatura_orvalho_max_na_hora_ant_aut_c                          23.9
# temperatura_orvalho_min_na_hora_ant_aut_c                          22.7
# umidade_rel_max_na_hora_ant_aut_perc                               93.0
# umidade_rel_min_na_hora_ant_aut_perc                               90.0
# umidade_relativa_do_ar_horaria_perc                                90.0
# vento_direção_horaria_gr__gr                                      115.0
# vento_rajada_maxima_ms                                              3.3
# vento_velocidade_horaria_ms                                         0.7
# data_hora                                           2023-01-01 10:00:00
# data                                                2023-01-01 00:00:00
# data_str                                                     2023-01-01
# hora                                                                 10
# dia                                                                   1
# mes                                                                   1
# ano                                                                2023
#
#                                                                      11  \
# precipitação_total_horário_mm                                       0.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb               1009.4
# pressão_atmosferica_max_na_hora_ant_aut_mb                       1009.4
# pressão_atmosferica_min_na_hora_ant_aut_mb                       1008.8
# radiacao                                                         1081.6
# temperatura_do_ar_bulbo_seco_horaria_c                             27.8
# temperatura_do_ponto_de_orvalho_c                                  22.7
# temperatura_máxima_na_hora_ant_aut_c                               28.5
# temperatura_mínima_na_hora_ant_aut_c                               25.3
# temperatura_orvalho_max_na_hora_ant_aut_c                          24.6
# temperatura_orvalho_min_na_hora_ant_aut_c                          22.7
# umidade_rel_max_na_hora_ant_aut_perc                               90.0
# umidade_rel_min_na_hora_ant_aut_perc                               74.0
# umidade_relativa_do_ar_horaria_perc                                74.0
# vento_direção_horaria_gr__gr                                      130.0
# vento_rajada_maxima_ms                                              3.6
# vento_velocidade_horaria_ms                                         0.9
# data_hora                                           2023-01-01 11:00:00
# data                                                2023-01-01 00:00:00
# data_str                                                     2023-01-01
# hora                                                                 11
# dia                                                                   1
# mes                                                                   1
# ano                                                                2023
#
#                                                                      12  \
# precipitação_total_horário_mm                                       0.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb               1009.4
# pressão_atmosferica_max_na_hora_ant_aut_mb                       1009.6
# pressão_atmosferica_min_na_hora_ant_aut_mb                       1009.3
# radiacao                                                         1700.4
# temperatura_do_ar_bulbo_seco_horaria_c                             28.6
# temperatura_do_ponto_de_orvalho_c                                  23.5
# temperatura_máxima_na_hora_ant_aut_c                               28.6
# temperatura_mínima_na_hora_ant_aut_c                               26.9
# temperatura_orvalho_max_na_hora_ant_aut_c                          23.8
# temperatura_orvalho_min_na_hora_ant_aut_c                          21.9
# umidade_rel_max_na_hora_ant_aut_perc                               81.0
# umidade_rel_min_na_hora_ant_aut_perc                               73.0
# umidade_relativa_do_ar_horaria_perc                                74.0
# vento_direção_horaria_gr__gr                                      144.0
# vento_rajada_maxima_ms                                              4.4
# vento_velocidade_horaria_ms                                         1.2
# data_hora                                           2023-01-01 12:00:00
# data                                                2023-01-01 00:00:00
# data_str                                                     2023-01-01
# hora                                                                 12
# dia                                                                   1
# mes                                                                   1
# ano                                                                2023
#
#                                                                      13
# precipitação_total_horário_mm                                       0.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb               1009.3
# pressão_atmosferica_max_na_hora_ant_aut_mb                       1009.4
# pressão_atmosferica_min_na_hora_ant_aut_mb                       1009.3
# radiacao                                                         2894.6
# temperatura_do_ar_bulbo_seco_horaria_c                             29.6
# temperatura_do_ponto_de_orvalho_c                                  23.8
# temperatura_máxima_na_hora_ant_aut_c                               29.7
# temperatura_mínima_na_hora_ant_aut_c                               28.4
# temperatura_orvalho_max_na_hora_ant_aut_c                          24.2
# temperatura_orvalho_min_na_hora_ant_aut_c                          22.9
# umidade_rel_max_na_hora_ant_aut_perc                               75.0
# umidade_rel_min_na_hora_ant_aut_perc                               70.0
# umidade_relativa_do_ar_horaria_perc                                71.0
# vento_direção_horaria_gr__gr                                      145.0
# vento_rajada_maxima_ms                                              4.8
# vento_velocidade_horaria_ms                                         1.2
# data_hora                                           2023-01-01 13:00:00
# data                                                2023-01-01 00:00:00
# data_str                                                     2023-01-01
# hora                                                                 13
# dia                                                                   1
# mes                                                                   1
# ano                                                                2023

# %% [markdown]
# ### Algumas estatisticas

# %%
numerics = ['float16', 'float32', 'float64']

df.select_dtypes(include=numerics).describe().T
# Out:
#                                                      count         mean  \
# precipitação_total_horário_mm                       4735.0     0.190539
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb  4735.0  1008.944688
# pressão_atmosferica_max_na_hora_ant_aut_mb          4735.0  1009.215143
# pressão_atmosferica_min_na_hora_ant_aut_mb          4735.0  1008.717297
# radiacao                                            4735.0  1374.269673
# temperatura_do_ar_bulbo_seco_horaria_c              4735.0    27.090053
# temperatura_do_ponto_de_orvalho_c                   4735.0    22.027117
# temperatura_máxima_na_hora_ant_aut_c                4735.0    27.750433
# temperatura_mínima_na_hora_ant_aut_c                4735.0    26.347392
# temperatura_orvalho_max_na_hora_ant_aut_c           4735.0    22.663506
# temperatura_orvalho_min_na_hora_ant_aut_c           4735.0    21.399366
# umidade_rel_max_na_hora_ant_aut_perc                4735.0    77.954382
# umidade_rel_min_na_hora_ant_aut_perc                4735.0    71.836748
# umidade_relativa_do_ar_horaria_perc                 4735.0    74.745723
# vento_direção_horaria_gr__gr                        4735.0   132.081943
# vento_rajada_maxima_ms                              4735.0     5.027645
# vento_velocidade_horaria_ms                         4735.0     1.340887
#
#                                                             std    min  \
# precipitação_total_horário_mm                          1.282495    0.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb     2.872539  999.7
# pressão_atmosferica_max_na_hora_ant_aut_mb             2.848353  999.9
# pressão_atmosferica_min_na_hora_ant_aut_mb             2.846851  999.5
# radiacao                                            1125.560423    0.0
# temperatura_do_ar_bulbo_seco_horaria_c                 2.316885   20.5
# temperatura_do_ponto_de_orvalho_c                      1.407656   15.2
# temperatura_máxima_na_hora_ant_aut_c                   2.447802   20.7
# temperatura_mínima_na_hora_ant_aut_c                   2.236428   20.5
# temperatura_orvalho_max_na_hora_ant_aut_c              1.425742   16.2
# temperatura_orvalho_min_na_hora_ant_aut_c              1.404543   14.8
# umidade_rel_max_na_hora_ant_aut_perc                  10.385413   49.0
# umidade_rel_min_na_hora_ant_aut_perc                  11.576081   40.0
# umidade_relativa_do_ar_horaria_perc                   10.880946   43.0
# vento_direção_horaria_gr__gr                          66.105187    1.0
# vento_rajada_maxima_ms                                 1.691827    0.7
# vento_velocidade_horaria_ms                            0.544323    0.1
#
#                                                        25%     50%      75%  \
# precipitação_total_horário_mm                          0.0     0.0     0.00
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb  1006.9  1008.6  1010.90
# pressão_atmosferica_max_na_hora_ant_aut_mb          1007.2  1008.9  1011.15
# pressão_atmosferica_min_na_hora_ant_aut_mb          1006.7  1008.4  1010.70
# radiacao                                             293.2  1223.6  2279.20
# temperatura_do_ar_bulbo_seco_horaria_c                25.3    27.0    28.80
# temperatura_do_ponto_de_orvalho_c                     21.1    22.2    23.00
# temperatura_máxima_na_hora_ant_aut_c                  25.8    27.8    29.70
# temperatura_mínima_na_hora_ant_aut_c                  24.6    26.3    28.00
# temperatura_orvalho_max_na_hora_ant_aut_c             21.8    22.8    23.70
# temperatura_orvalho_min_na_hora_ant_aut_c             20.5    21.6    22.40
# umidade_rel_max_na_hora_ant_aut_perc                  70.0    78.0    87.00
# umidade_rel_min_na_hora_ant_aut_perc                  63.0    71.0    80.00
# umidade_relativa_do_ar_horaria_perc                   67.0    74.0    83.00
# vento_direção_horaria_gr__gr                          80.0   137.0   169.00
# vento_rajada_maxima_ms                                 3.9     5.0     6.00
# vento_velocidade_horaria_ms                            1.0     1.3     1.60
#
#                                                        max
# precipitação_total_horário_mm                         38.4
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb  1018.2
# pressão_atmosferica_max_na_hora_ant_aut_mb          1018.3
# pressão_atmosferica_min_na_hora_ant_aut_mb          1018.0
# radiacao                                            4202.3
# temperatura_do_ar_bulbo_seco_horaria_c                33.8
# temperatura_do_ponto_de_orvalho_c                     26.2
# temperatura_máxima_na_hora_ant_aut_c                  34.1
# temperatura_mínima_na_hora_ant_aut_c                  32.4
# temperatura_orvalho_max_na_hora_ant_aut_c             27.4
# temperatura_orvalho_min_na_hora_ant_aut_c             24.6
# umidade_rel_max_na_hora_ant_aut_perc                  96.0
# umidade_rel_min_na_hora_ant_aut_perc                  96.0
# umidade_relativa_do_ar_horaria_perc                   96.0
# vento_direção_horaria_gr__gr                         360.0
# vento_rajada_maxima_ms                                14.5
# vento_velocidade_horaria_ms                            4.4

# %% [markdown]
# ### Plot por mes

# %%
set_plot_size(11, 5)
df_month = filter_between(df, "hora", 10, 20)

df_month = df_month[["mes", "radiacao"]].groupby(['mes'])\
['radiacao'].agg(['mean','std']).reset_index()

sns.lineplot(data=df_month, x=df_month["mes"], y=df_month["mean"])
# Out:
# <Axes: xlabel='mes', ylabel='mean'>

# %% [markdown]
# ### Por hora

# %%
df_hour = filter_between(df, "hora", 10, 20)

df_hour = df_hour[["hora", "radiacao"]].groupby(['hora']).mean().reset_index()

sns.lineplot(data=df_hour, x=df_hour["hora"], y=df_hour["radiacao"])
# Out:
# <Axes: xlabel='hora', ylabel='radiacao'>

# %% [markdown]
# #### Hora com o vento como `hue`

# %%
df_hour_wind = filter_between(df, "hora", 10, 20)
df_hour_wind = df_hour_wind[[
    "hora", 
    "radiacao", 
    "vento_rajada_maxima_ms"]]\
.fillna(0)

df_hour_wind["wind_catg"] = create_category("vento_rajada_maxima_ms", df_hour_wind)
sns.lineplot(data=df_hour_wind, x=df_hour_wind["hora"], y=df_hour_wind["radiacao"], hue=df_hour_wind["wind_catg"])
# Out:
# [ 0.7  4.   5.   6.  14.5]
# <Axes: xlabel='hora', ylabel='radiacao'>

# %% [markdown]
# #### Hora com a pressão atmo. como `hue`

# %%
df_hour_press = filter_between(df, "hora", 10, 20)
df_hour_press = df_hour_press[[
    "hora", 
    "radiacao", 
    "pressao_atmosferica_ao_nivel_da_estacao_horaria_mb"]]\
.fillna(0)

df_hour_press["press_catg"] = create_category("pressao_atmosferica_ao_nivel_da_estacao_horaria_mb", df_hour_press)
sns.lineplot(data=df_hour_press, x=df_hour_press["hora"], y=df_hour_press["radiacao"], hue=df_hour_press["press_catg"])
# Out:
# [ 999.7 1007.  1008.8 1011.  1018.2]
# <Axes: xlabel='hora', ylabel='radiacao'>

# %% [markdown]
# #### Hora com a temperatura como `hue`

# %%
df_temp = filter_between(df, "hora", 10, 20)

df_temp = df_temp[[
    "hora", 
    "radiacao", 
    "temperatura_do_ar_bulbo_seco_horaria_c"]]\
.fillna(0)

df_temp["temp_catg"] = create_category("temperatura_do_ar_bulbo_seco_horaria_c", df_temp)
sns.lineplot(data=df_temp, x=df_temp["hora"], y=df_temp["radiacao"], hue=df_temp["temp_catg"])
# Out:
# [20.9 25.8 27.5 29.2 33.8]
# <Axes: xlabel='hora', ylabel='radiacao'>

# %% [markdown]
# #### Hora com a umidade como `hue`

# %%
df_hum = filter_between(df, "hora", 10, 20)

df_hum = df_hum[[
    "hora", 
    "radiacao", 
    "umidade_relativa_do_ar_horaria_perc"]]\
.fillna(0)

df_hum["hum_catg"] = create_category("umidade_relativa_do_ar_horaria_perc", df_hum)
sns.lineplot(data=df_hum, x=df_hum["hora"], y=df_hum["radiacao"], hue=df_hum["hum_catg"])
# Out:
# [43. 65. 72. 81. 96.]
# <Axes: xlabel='hora', ylabel='radiacao'>

# %% [markdown]
# #### Relação linear entre radiação e vento

# %%
df_rel_wind = filter_between(df, "hora", 10, 20)
sns.lineplot(data=df_rel_wind, x=df_rel_wind["vento_velocidade_horaria_ms"], y=df_rel_wind["radiacao"])
# Out:
# <Axes: xlabel='vento_velocidade_horaria_ms', ylabel='radiacao'>

# %% [markdown]
# #### Relação linear entre radiação e a umidade

# %%
df_rel_hum = filter_between(df, "hora", 10, 20)
sns.lineplot(data=df_rel_hum, x=df_rel_hum["umidade_relativa_do_ar_horaria_perc"], y=df_rel_hum["radiacao"])
# Out:
# <Axes: xlabel='umidade_relativa_do_ar_horaria_perc', ylabel='radiacao'>

# %% [markdown]
# ### Serie temporal ao longo do ano

# %%
df_test = filter_between(df, "hora", 10, 20)
sns.lineplot(data=df_test, x="data", y="radiacao")
# Out:
# <Axes: xlabel='data', ylabel='radiacao'>

# %% [markdown]
# ### Em uma semana

# %%
df_test = filter_between(df, "hora", 10, 20)
df_test = filter_between(df_test, "data", "2023-01-01", "2023-01-08")
df_test["rad_mean"] = df_test["radiacao"].mean()
sns.lineplot(data=df_test, x="data_hora", y="radiacao")
# Out:
# <Axes: xlabel='data_hora', ylabel='radiacao'>

# %% [markdown]
# ### Verão

# %%
set_plot_size(15, 3)
df_summer = filter_between(df, "data", "2023-01-01", "2023-03-21")
df_summer = filter_between(df_summer, "hora", 10, 17)

sns.lineplot(data=df_summer, x="data", y="radiacao")
# Out:
# <Axes: xlabel='data', ylabel='radiacao'>

# %% [markdown]
# ### Outono

# %%
set_plot_size(15, 3)
df_test = filter_between(df, "data", "2023-03-21", "2023-06-21")
df_test = filter_between(df_test, "hora", 10, 17)

sns.lineplot(data=df_test, x="data", y="radiacao")
# Out:
# <Axes: xlabel='data', ylabel='radiacao'>

# %% [markdown]
# ### Inverno

# %%
set_plot_size(15, 3)
df_test = filter_between(df, "data", "2023-06-21", "2023-09-23")
df_test = filter_between(df_test, "hora", 10, 17)

sns.lineplot(data=df_test, x="data", y="radiacao")
# Out:
# <Axes: xlabel='data', ylabel='radiacao'>

# %% [markdown]
# ### Primavera

# %%
set_plot_size(15, 3)
df_test = filter_between(df, "data", "2023-09-23", "2023-12-21")
df_test = filter_between(df_test, "hora", 10, 17)

sns.lineplot(data=df_test, x="data", y="radiacao")
# Out:
# <Axes: xlabel='data', ylabel='radiacao'>

# %% [markdown]
# ### Media movel

# %%
df_test = filter_between(df, "hora", 10, 17)
df_test["media_movel"] = df_test.radiacao.rolling(8).mean()
sns.lineplot(data=df_test, x="data", y="media_movel")
# Out:
# <Axes: xlabel='data', ylabel='media_movel'>

# %% [markdown]
# ### Aumento e aceleração

# %%
df_test = filter_between(df, "hora", 10, 17)
df_test['aumento'] = df_test.radiacao.diff()
sns.lineplot(data=df_test, x="data", y="aumento")
# Out:
# <Axes: xlabel='data', ylabel='aumento'>

# %%
df_test['aceleracao'] = df_test.aumento.diff()
sns.lineplot(data=df_test, x="data", y="aceleracao")
# Out:
# <Axes: xlabel='data', ylabel='aceleracao'>

# %% [markdown]
# ### Autocorrelação

# %%
df_test = filter_between(df, "hora", 10, 17)
df_test = filter_between(df_test, "data", "2023-03-21", "2023-03-28")
ax = plt.figure(figsize=(12,6))
ax.suptitle("Correlação", fontsize=18, x=0.26, y=0.95)
autocorrelation_plot(df_test.radiacao)
ax=ax

# %% [markdown]
# ### Decomposição

# %%
set_plot_size(15, 8)
df_test = filter_between(df, "hora", 10, 17)
df_test = filter_between(df_test, "data", "2023-01-01", "2023-03-21")

resultado = seasonal_decompose(df_test[["radiacao", "data"]].set_index('data'), period=90)
ax = resultado.plot()

# %% [markdown]
# ### Teste de estacionariedade

# %%
result = adfuller(df_test["radiacao"], autolag="AIC")
print('Estatística ADF: {:0.2f}'.format(result[0]))
print('Número de atrasos: {}'.format(result[2]))
print('Valor p: {:0.3f}'.format(result[1]))
for key, value in result[4].items():
    print('Valores críticos:')
    print("{}, {:0.2f}".format(key,value))
# Out:
# Estatística ADF: -5.19
# Número de atrasos: 17
# Valor p: 0.000
# Valores críticos:
# 1%, -3.44
# Valores críticos:
# 5%, -2.87
# Valores críticos:
# 10%, -2.57

# %% [markdown]
# ### Box-Cox

# %%
# Importar bibliotecas
from scipy.stats import boxcox
# Calcular melhor valor de lambda para a série temporal
df_box_cox = filter_between(df, "data", "2023-01-01", "2023-03-21")
df_box_cox = filter_between(df_box_cox, "hora", 10, 17)
serie_temporal2, lambda_boxcox = boxcox(df_box_cox["radiacao"])

# %%
df_box_cox["rad"] = serie_temporal2

# %%
set_plot_size(11, 5)
sns.lineplot(data=df_box_cox, x="data", y="rad")
# Out:
# <Axes: xlabel='data', ylabel='rad'>
