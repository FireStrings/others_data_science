# %% [markdown]
# # Definitions
# - Definir estações
# - Artigo para ler: https://latamt.ieeer9.org/index.php/transactions/article/view/5563
# - Plotar hora a hora, e o describe
# - Transformação logaritmica, para variacia não constante?
# - Método Box-Cox ou deflacionar a série
# - Modelar a serie temporal
#   - Normality hypothesis tests, Anderson-Darling and Shapiro-Wilk
#   - Decompor em 3 partes: tendência, sazonalidade e resíduo
# - Aplicar estacionariedade
# - Verificar precipitação, quando tiver.
# - A press atmo do nivel da estacao ja é a media
# - Usar temp. Bulbo seco
# - Agrupar por estacoes do ano (verao, inverno, etc)
# - Corte as 5h as 21h
# - Verificar umidade no litoral
# - Pegar estacoes proximas, ir do litoral ao interior
# - Pegar principalmente duas regioes (bahia e sul, por exemplo)
# - Transfer learning entre estacoes nas regioes

# %% [markdown]
# ### Escolhendo estações
# Iremos escolher duas regiões:
# - Bahia, pegando algumas estações (umas 3) e indo do litoral até o interior.
# - RS, com o mesmo comportamento da primeira.
#
# Bahia:
# - A401
# - A413
# - A440
#
# RS:
# - A801
# - A840
# - A893
#
# Nesse Notebook, analisaremos os dados da estação A840 (Bento Gonçalves, Rio Grande do Sul), que fica entre o litoral e a área central do estado.

# %% [markdown]
# ### Imports

# %%
# %run Utils.ipynb

# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from pandas.plotting import autocorrelation_plot
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
dict_files = get_files(n=None)

# %%
# dict_files.keys()
print(dict_files["A840"][0])
# Out:
# REGIAO:;S
# UF:;RS
# ESTACAO:;BENTO GONCALVES
# CODIGO (WMO):;A840
# LATITUDE:;-29,164581
# LONGITUDE:;-51,534202
# ALTITUDE:;623,27
# DATA DE FUNDACAO:;01/12/06

# %%
dict_files["A840"][1]
# Out:
# 'data/estacoes_solares/2023/INMET_S_RS_A840_BENTO GONCALVES_01-01-2023_A_31-12-2023.CSV'

# %% [markdown]
# ### Pre processamento

# %%
df = load(dict_files["A840"][1])
df = renameDatasetColumns(df)
df = transform_datetime(df)
df = create_datetime_feature(df)
df = create_split_date_features(df)
df = removeNulls(df, "radiacao")
df = change_types(df)

# %%
df.head().T
# Out:
#                                                                      9   \
# precipitação_total_horário_mm                                       0.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb                943.4
# pressão_atmosferica_max_na_hora_ant_aut_mb                        943.4
# pressão_atmosferica_min_na_hora_ant_aut_mb                        942.6
# radiacao                                                           23.4
# temperatura_do_ar_bulbo_seco_horaria_c                             20.9
# temperatura_do_ponto_de_orvalho_c                                  16.4
# temperatura_máxima_na_hora_ant_aut_c                               21.6
# temperatura_mínima_na_hora_ant_aut_c                               20.8
# temperatura_orvalho_max_na_hora_ant_aut_c                          16.4
# temperatura_orvalho_min_na_hora_ant_aut_c                          16.2
# umidade_rel_max_na_hora_ant_aut_perc                               76.0
# umidade_rel_min_na_hora_ant_aut_perc                               72.0
# umidade_relativa_do_ar_horaria_perc                                76.0
# vento_direção_horaria_gr__gr                                       46.0
# vento_rajada_maxima_ms                                              8.0
# vento_velocidade_horaria_ms                                         3.1
# data_hora                                           2023-01-01 09:00:00
# data                                                2023-01-01 00:00:00
# data_str                                                     2023-01-01
# hora                                                                  9
# dia                                                                   1
# mes                                                                   1
# ano                                                                2023
#
#                                                                      10  \
# precipitação_total_horário_mm                                       0.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb                943.4
# pressão_atmosferica_max_na_hora_ant_aut_mb                        943.5
# pressão_atmosferica_min_na_hora_ant_aut_mb                        943.3
# radiacao                                                          463.9
# temperatura_do_ar_bulbo_seco_horaria_c                             21.7
# temperatura_do_ponto_de_orvalho_c                                  17.0
# temperatura_máxima_na_hora_ant_aut_c                               21.8
# temperatura_mínima_na_hora_ant_aut_c                               20.9
# temperatura_orvalho_max_na_hora_ant_aut_c                          17.2
# temperatura_orvalho_min_na_hora_ant_aut_c                          16.5
# umidade_rel_max_na_hora_ant_aut_perc                               76.0
# umidade_rel_min_na_hora_ant_aut_perc                               74.0
# umidade_relativa_do_ar_horaria_perc                                74.0
# vento_direção_horaria_gr__gr                                       48.0
# vento_rajada_maxima_ms                                              8.3
# vento_velocidade_horaria_ms                                         3.8
# data_hora                                           2023-01-01 10:00:00
# data                                                2023-01-01 00:00:00
# data_str                                                     2023-01-01
# hora                                                                 10
# dia                                                                   1
# mes                                                                   1
# ano                                                                2023
#
#                                                                      11  \
# precipitação_total_horário_mm                                       0.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb                944.0
# pressão_atmosferica_max_na_hora_ant_aut_mb                        944.0
# pressão_atmosferica_min_na_hora_ant_aut_mb                        943.4
# radiacao                                                         1340.3
# temperatura_do_ar_bulbo_seco_horaria_c                             23.0
# temperatura_do_ponto_de_orvalho_c                                  16.9
# temperatura_máxima_na_hora_ant_aut_c                               23.2
# temperatura_mínima_na_hora_ant_aut_c                               21.7
# temperatura_orvalho_max_na_hora_ant_aut_c                          17.4
# temperatura_orvalho_min_na_hora_ant_aut_c                          16.8
# umidade_rel_max_na_hora_ant_aut_perc                               75.0
# umidade_rel_min_na_hora_ant_aut_perc                               68.0
# umidade_relativa_do_ar_horaria_perc                                69.0
# vento_direção_horaria_gr__gr                                       34.0
# vento_rajada_maxima_ms                                              8.5
# vento_velocidade_horaria_ms                                         2.7
# data_hora                                           2023-01-01 11:00:00
# data                                                2023-01-01 00:00:00
# data_str                                                     2023-01-01
# hora                                                                 11
# dia                                                                   1
# mes                                                                   1
# ano                                                                2023
#
#                                                                      12  \
# precipitação_total_horário_mm                                       0.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb                943.9
# pressão_atmosferica_max_na_hora_ant_aut_mb                        944.1
# pressão_atmosferica_min_na_hora_ant_aut_mb                        943.9
# radiacao                                                         2154.3
# temperatura_do_ar_bulbo_seco_horaria_c                             24.7
# temperatura_do_ponto_de_orvalho_c                                  16.8
# temperatura_máxima_na_hora_ant_aut_c                               25.0
# temperatura_mínima_na_hora_ant_aut_c                               22.9
# temperatura_orvalho_max_na_hora_ant_aut_c                          17.8
# temperatura_orvalho_min_na_hora_ant_aut_c                          16.8
# umidade_rel_max_na_hora_ant_aut_perc                               70.0
# umidade_rel_min_na_hora_ant_aut_perc                               61.0
# umidade_relativa_do_ar_horaria_perc                                62.0
# vento_direção_horaria_gr__gr                                       39.0
# vento_rajada_maxima_ms                                              6.0
# vento_velocidade_horaria_ms                                         2.7
# data_hora                                           2023-01-01 12:00:00
# data                                                2023-01-01 00:00:00
# data_str                                                     2023-01-01
# hora                                                                 12
# dia                                                                   1
# mes                                                                   1
# ano                                                                2023
#
#                                                                      13
# precipitação_total_horário_mm                                       0.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb                943.6
# pressão_atmosferica_max_na_hora_ant_aut_mb                        944.0
# pressão_atmosferica_min_na_hora_ant_aut_mb                        943.5
# radiacao                                                         2846.2
# temperatura_do_ar_bulbo_seco_horaria_c                             26.6
# temperatura_do_ponto_de_orvalho_c                                  16.9
# temperatura_máxima_na_hora_ant_aut_c                               26.7
# temperatura_mínima_na_hora_ant_aut_c                               24.6
# temperatura_orvalho_max_na_hora_ant_aut_c                          18.0
# temperatura_orvalho_min_na_hora_ant_aut_c                          16.4
# umidade_rel_max_na_hora_ant_aut_perc                               63.0
# umidade_rel_min_na_hora_ant_aut_perc                               54.0
# umidade_relativa_do_ar_horaria_perc                                55.0
# vento_direção_horaria_gr__gr                                       22.0
# vento_rajada_maxima_ms                                              6.7
# vento_velocidade_horaria_ms                                         3.3
# data_hora                                           2023-01-01 13:00:00
# data                                                2023-01-01 00:00:00
# data_str                                                     2023-01-01
# hora                                                                 13
# dia                                                                   1
# mes                                                                   1
# ano                                                                2023

# %% [markdown]
# ### Algumas estatisticas

# %%
numerics = ['float16', 'float32', 'float64']

df.select_dtypes(include=numerics).describe().T
# Out:
#                                                      count         mean  \
# precipitação_total_horário_mm                       4690.0     0.268188
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb  4744.0   943.605333
# pressão_atmosferica_max_na_hora_ant_aut_mb          4742.0   943.921679
# pressão_atmosferica_min_na_hora_ant_aut_mb          4742.0   943.311767
# radiacao                                            4744.0  1226.961003
# temperatura_do_ar_bulbo_seco_horaria_c              4744.0    19.777277
# temperatura_do_ponto_de_orvalho_c                   4744.0    14.117643
# temperatura_máxima_na_hora_ant_aut_c                4742.0    20.370730
# temperatura_mínima_na_hora_ant_aut_c                4742.0    18.977267
# temperatura_orvalho_max_na_hora_ant_aut_c           4742.0    14.799726
# temperatura_orvalho_min_na_hora_ant_aut_c           4742.0    13.450822
# umidade_rel_max_na_hora_ant_aut_perc                4742.0    75.789119
# umidade_rel_min_na_hora_ant_aut_perc                4742.0    69.717419
# umidade_relativa_do_ar_horaria_perc                 4744.0    72.357715
# vento_direção_horaria_gr__gr                        4656.0   156.131229
# vento_rajada_maxima_ms                              4650.0     6.535634
# vento_velocidade_horaria_ms                         4656.0     2.702040
#
#                                                             std    min  \
# precipitação_total_horário_mm                          1.436726    0.0
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb     4.416611  928.2
# pressão_atmosferica_max_na_hora_ant_aut_mb             4.359978  928.6
# pressão_atmosferica_min_na_hora_ant_aut_mb             4.480105  926.6
# radiacao                                            1088.858395    0.0
# temperatura_do_ar_bulbo_seco_horaria_c                 5.460587    2.6
# temperatura_do_ponto_de_orvalho_c                      4.307120   -4.5
# temperatura_máxima_na_hora_ant_aut_c                   5.636156    2.8
# temperatura_mínima_na_hora_ant_aut_c                   5.388534    2.0
# temperatura_orvalho_max_na_hora_ant_aut_c              4.238936   -1.5
# temperatura_orvalho_min_na_hora_ant_aut_c              4.411596   -6.3
# umidade_rel_max_na_hora_ant_aut_perc                  15.919429   25.0
# umidade_rel_min_na_hora_ant_aut_perc                  18.181114   15.0
# umidade_relativa_do_ar_horaria_perc                   17.104459   17.0
# vento_direção_horaria_gr__gr                         105.208376    1.0
# vento_rajada_maxima_ms                                 2.490650    1.1
# vento_velocidade_horaria_ms                            1.185075    0.2
#
#                                                         25%    50%       75%  \
# precipitação_total_horário_mm                         0.000    0.0     0.000
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb  940.600  943.7   946.600
# pressão_atmosferica_max_na_hora_ant_aut_mb          940.900  944.0   946.900
# pressão_atmosferica_min_na_hora_ant_aut_mb          940.300  943.4   946.400
# radiacao                                            228.725  954.7  2058.750
# temperatura_do_ar_bulbo_seco_horaria_c               16.400   19.9    23.500
# temperatura_do_ponto_de_orvalho_c                    11.600   14.9    17.325
# temperatura_máxima_na_hora_ant_aut_c                 16.700   20.4    24.300
# temperatura_mínima_na_hora_ant_aut_c                 15.600   19.1    22.600
# temperatura_orvalho_max_na_hora_ant_aut_c            12.300   15.5    18.000
# temperatura_orvalho_min_na_hora_ant_aut_c            10.800   14.3    16.800
# umidade_rel_max_na_hora_ant_aut_perc                 64.000   78.0    90.000
# umidade_rel_min_na_hora_ant_aut_perc                 57.000   71.0    86.000
# umidade_relativa_do_ar_horaria_perc                  60.000   74.0    88.000
# vento_direção_horaria_gr__gr                         57.000  145.0   243.000
# vento_rajada_maxima_ms                                4.800    6.2     8.000
# vento_velocidade_horaria_ms                           1.800    2.6     3.400
#
#                                                        max
# precipitação_total_horário_mm                         28.4
# pressao_atmosferica_ao_nivel_da_estacao_horaria_mb   957.6
# pressão_atmosferica_max_na_hora_ant_aut_mb           957.7
# pressão_atmosferica_min_na_hora_ant_aut_mb           957.5
# radiacao                                            3988.8
# temperatura_do_ar_bulbo_seco_horaria_c                34.2
# temperatura_do_ponto_de_orvalho_c                     24.1
# temperatura_máxima_na_hora_ant_aut_c                  35.0
# temperatura_mínima_na_hora_ant_aut_c                  33.3
# temperatura_orvalho_max_na_hora_ant_aut_c             24.7
# temperatura_orvalho_min_na_hora_ant_aut_c             23.5
# umidade_rel_max_na_hora_ant_aut_perc                  98.0
# umidade_rel_min_na_hora_ant_aut_perc                  98.0
# umidade_relativa_do_ar_horaria_perc                   98.0
# vento_direção_horaria_gr__gr                         360.0
# vento_rajada_maxima_ms                                29.6
# vento_velocidade_horaria_ms                            9.3

# %% [markdown]
# ### Plot por mes

# %%
set_plot_size(11, 5)
df_month = filter_between(df, "hora", 10, 20)

df_month = df_month[["mes", "radiacao"]].groupby(['mes'])\
['radiacao'].agg(['mean','std']).reset_index()

sns.lineplot(data=df_month, x=df_month["mes"], y=df_month["mean"])
# Out:
# <Axes: xlabel='mes', ylabel='mean'>

# %% [markdown]
# ### Por hora

# %%
df_hour = filter_between(df, "hora", 10, 20)

df_hour = df_hour[["hora", "radiacao"]].groupby(['hora']).mean().reset_index()

sns.lineplot(data=df_hour, x=df_hour["hora"], y=df_hour["radiacao"])
# Out:
# <Axes: xlabel='hora', ylabel='radiacao'>

# %% [markdown]
# #### Hora com o vento como `hue`

# %%
df_hour_wind = filter_between(df, "hora", 10, 20)
df_hour_wind = df_hour_wind[[
    "hora", 
    "radiacao", 
    "vento_rajada_maxima_ms"]]\
.fillna(0)

df_hour_wind["wind_catg"] = create_category("vento_rajada_maxima_ms", df_hour_wind)
sns.lineplot(data=df_hour_wind, x=df_hour_wind["hora"], y=df_hour_wind["radiacao"], hue=df_hour_wind["wind_catg"])
# Out:
# [ 0.   4.8  6.1  7.8 29.6]
# <Axes: xlabel='hora', ylabel='radiacao'>

# %% [markdown]
# #### Hora com a pressão atmo. como `hue`

# %%
df_hour_press = filter_between(df, "hora", 10, 20)
df_hour_press = df_hour_press[[
    "hora", 
    "radiacao", 
    "pressao_atmosferica_ao_nivel_da_estacao_horaria_mb"]]\
.fillna(0)

df_hour_press["press_catg"] = create_category("pressao_atmosferica_ao_nivel_da_estacao_horaria_mb", df_hour_press)
sns.lineplot(data=df_hour_press, x=df_hour_press["hora"], y=df_hour_press["radiacao"], hue=df_hour_press["press_catg"])
# Out:
# [928.2 941.1 944.2 947.  957.6]
# <Axes: xlabel='hora', ylabel='radiacao'>

# %% [markdown]
# #### Hora com a temperatura como `hue`

# %%
df_temp = filter_between(df, "hora", 10, 20)

df_temp = df_temp[[
    "hora", 
    "radiacao", 
    "temperatura_do_ar_bulbo_seco_horaria_c"]]\
.fillna(0)

df_temp["temp_catg"] = create_category("temperatura_do_ar_bulbo_seco_horaria_c", df_temp)
sns.lineplot(data=df_temp, x=df_temp["hora"], y=df_temp["radiacao"], hue=df_temp["temp_catg"])
# Out:
# [ 2.6 16.4 19.9 23.7 34.2]
# <Axes: xlabel='hora', ylabel='radiacao'>

# %% [markdown]
# #### Hora com a umidade como `hue`

# %%
df_hum = filter_between(df, "hora", 10, 20)

df_hum = df_hum[[
    "hora", 
    "radiacao", 
    "umidade_relativa_do_ar_horaria_perc"]]\
.fillna(0)

df_hum["hum_catg"] = create_category("umidade_relativa_do_ar_horaria_perc", df_hum)
sns.lineplot(data=df_hum, x=df_hum["hora"], y=df_hum["radiacao"], hue=df_hum["hum_catg"])
# Out:
# [17. 59. 72. 86. 98.]
# <Axes: xlabel='hora', ylabel='radiacao'>

# %% [markdown]
# #### Relação linear entre radiação e vento

# %%
df_rel_wind = filter_between(df, "hora", 10, 20)
sns.lineplot(data=df_rel_wind, x=df_rel_wind["vento_velocidade_horaria_ms"], y=df_rel_wind["radiacao"])
# Out:
# <Axes: xlabel='vento_velocidade_horaria_ms', ylabel='radiacao'>

# %% [markdown]
# #### Relação linear entre radiação e a umidade

# %%
df_rel_hum = filter_between(df, "hora", 10, 20)
sns.lineplot(data=df_rel_hum, x=df_rel_hum["umidade_relativa_do_ar_horaria_perc"], y=df_rel_hum["radiacao"])
# Out:
# <Axes: xlabel='umidade_relativa_do_ar_horaria_perc', ylabel='radiacao'>

# %% [markdown]
# ### Serie temporal ao longo do ano

# %%
df_test = filter_between(df, "hora", 10, 20)
sns.lineplot(data=df_test, x="data", y="radiacao")
# Out:
# <Axes: xlabel='data', ylabel='radiacao'>

# %% [markdown]
# ### Em uma semana

# %%
df_test = filter_between(df, "hora", 10, 20)
df_test = filter_between(df_test, "data", "2023-01-01", "2023-01-08")
df_test["rad_mean"] = df_test["radiacao"].mean()
sns.lineplot(data=df_test, x="data_hora", y="radiacao")
# Out:
# <Axes: xlabel='data_hora', ylabel='radiacao'>

# %% [markdown]
# ### Verão

# %%
set_plot_size(15, 3)
df_summer = filter_between(df, "data", "2023-01-01", "2023-03-21")
df_summer = filter_between(df_summer, "hora", 10, 17)

sns.lineplot(data=df_summer, x="data", y="radiacao")
# Out:
# <Axes: xlabel='data', ylabel='radiacao'>

# %% [markdown]
# ### Outono

# %%
set_plot_size(15, 3)
df_test = filter_between(df, "data", "2023-03-21", "2023-06-21")
df_test = filter_between(df_test, "hora", 10, 17)

sns.lineplot(data=df_test, x="data", y="radiacao")
# Out:
# <Axes: xlabel='data', ylabel='radiacao'>

# %% [markdown]
# ### Inverno

# %%
set_plot_size(15, 3)
df_test = filter_between(df, "data", "2023-06-21", "2023-09-23")
df_test = filter_between(df_test, "hora", 10, 17)

sns.lineplot(data=df_test, x="data", y="radiacao")
# Out:
# <Axes: xlabel='data', ylabel='radiacao'>

# %% [markdown]
# ### Primavera

# %%
set_plot_size(15, 3)
df_test = filter_between(df, "data", "2023-09-23", "2023-12-21")
df_test = filter_between(df_test, "hora", 10, 17)

sns.lineplot(data=df_test, x="data", y="radiacao")
# Out:
# <Axes: xlabel='data', ylabel='radiacao'>

# %% [markdown]
# ### Media movel

# %%
df_test = filter_between(df, "hora", 10, 17)
df_test["media_movel"] = df_test.radiacao.rolling(8).mean()
sns.lineplot(data=df_test, x="data", y="media_movel")
# Out:
# <Axes: xlabel='data', ylabel='media_movel'>

# %% [markdown]
# ### Aumento e aceleração

# %%
df_test = filter_between(df, "hora", 10, 17)
df_test['aumento'] = df_test.radiacao.diff()
sns.lineplot(data=df_test, x="data", y="aumento")
# Out:
# <Axes: xlabel='data', ylabel='aumento'>

# %%
df_test['aceleracao'] = df_test.aumento.diff()
sns.lineplot(data=df_test, x="data", y="aceleracao")
# Out:
# <Axes: xlabel='data', ylabel='aceleracao'>

# %% [markdown]
# ### Autocorrelação

# %%
df_test = filter_between(df, "hora", 10, 17)
df_test = filter_between(df_test, "data", "2023-03-21", "2023-03-28")
ax = plt.figure(figsize=(12,6))
ax.suptitle("Correlação", fontsize=18, x=0.26, y=0.95)
autocorrelation_plot(df_test.radiacao)
ax=ax

# %% [markdown]
# ### Decomposição

# %%
set_plot_size(15, 8)
df_test = filter_between(df, "hora", 10, 17)
df_test = filter_between(df_test, "data", "2023-01-01", "2023-03-21")

resultado = seasonal_decompose(df_test[["radiacao", "data"]].set_index('data'), period=90)
ax = resultado.plot()

# %% [markdown]
# ### Teste de estacionariedade

# %%
result = adfuller(df_test["radiacao"], autolag="AIC")
print('Estatística ADF: {:0.2f}'.format(result[0]))
print('Número de atrasos: {}'.format(result[2]))
print('Valor p: {:0.3f}'.format(result[1]))
for key, value in result[4].items():
    print('Valores críticos:')
    print("{}, {:0.2f}".format(key,value))
# Out:
# Estatística ADF: -5.02
# Número de atrasos: 17
# Valor p: 0.000
# Valores críticos:
# 1%, -3.44
# Valores críticos:
# 5%, -2.87
# Valores críticos:
# 10%, -2.57

# %% [markdown]
# ### Box-Cox

# %%
# Importar bibliotecas
from scipy.stats import boxcox
# Calcular melhor valor de lambda para a série temporal
df_box_cox = filter_between(df, "data", "2023-01-01", "2023-03-21")
df_box_cox = filter_between(df_box_cox, "hora", 10, 17)
serie_temporal2, lambda_boxcox = boxcox(df_box_cox["radiacao"])

# %%
df_box_cox["rad"] = serie_temporal2

# %%
set_plot_size(11, 5)
sns.lineplot(data=df_box_cox, x="data", y="rad")
# Out:
# <Axes: xlabel='data', ylabel='rad'>
