# %%
import pandas as pd
import numpy as no
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("data/weatherAUS.csv")

# %%
data.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
data['data'] = pd.to_datetime(data['Date'])
data2 = data.groupby("data").agg("mean")

# %%
ax = sns.lineplot(x='data', y='MaxTemp', data=data2.iloc[0:1000])
sns.set_palette("Accent")
sns.set_style("darkgrid")
ax.figure.set_size_inches(12,6)
ax.set_title("Temperaturas", loc='left', fontsize=18)
ax.set_xlabel("Tempo", fontsize=14)
ax.set_ylabel("Temp", fontsize=14)
ax = ax

# %%
data2['aumento'] = data2.MaxTemp.diff()

# %%
ax = sns.lineplot(x='data', y='aumento', data=data2)
ax.figure.set_size_inches(12,6)
ax.set_title("Aumento das Temperaturas", loc='left', fontsize=18)
ax.set_xlabel("Tempo", fontsize=14)
ax.set_ylabel("Aumento", fontsize=14)
ax = ax

# %%
data2.head()
# Out:
#             MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# data
# 2007-11-01      8.0     24.3       0.0          3.4       6.3           30.0
# 2007-11-02     14.0     26.9       3.6          4.4       9.7           39.0
# 2007-11-03     13.7     23.4       3.6          5.8       3.3           85.0
# 2007-11-04     13.3     15.5      39.8          7.2       9.1           54.0
# 2007-11-05      7.6     16.1       2.8          5.6      10.6           50.0
#
#             WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# data
# 2007-11-01           6.0          20.0         68.0         29.0       1019.7
# 2007-11-02           4.0          17.0         80.0         36.0       1012.4
# 2007-11-03           6.0           6.0         82.0         69.0       1009.5
# 2007-11-04          30.0          24.0         62.0         56.0       1005.5
# 2007-11-05          20.0          28.0         68.0         49.0       1018.3
#
# ...
